# %%
import requests
import random
import numpy as np

word_site = "http://svnweb.freebsd.org/csrg/share/dict/words?view=co&content-type=text/plain"
response = requests.get(word_site)
WORDS = response.content.splitlines()
proper = [word for word in WORDS if word[0].isupper()]
not_proper = [word for word in WORDS if not word[0].isupper()]

class formWords:
    def __init__(self, proper, not_proper):
        self.proper = proper
        self.not_proper = not_proper
        
    def randomProper(self):
        return self.proper[np.random.randint(0,len(self.proper))]
    
    def randomNonProper(self):
        return self.not_proper[np.random.randint(0,len(self.not_proper))]
        
    def randomNumber(self,digits):
        return str(random.sample(range(10 ** (digits - 1), 10 ** (digits)), 1)[0])
    
    def randomPostfix(self):
        postfix = ['Street','Ave', 'Blvd', 'Lane', 'Court']
        return postfix[np.random.randint(1,len(postfix))]
    
    def randomEmailProvider(self):
        provider = ['gmail','yahoo', 'live', 'compuserve', 'aol']
        return provider[np.random.randint(1,len(provider))]
    
    def randomState(self):
        states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
        return states[np.random.randint(1,len(states))]
        
    def generateText(self, blog_length):
        form = self.getForm()
        blog = []
        for x in range(blog_length):
            choice = np.random.randint(1,50)
            if choice < 38:
                blog += [self.randomNonProper()]
            elif choice < 40:
                blog += [form['email']()]
            elif choice < 44:
                blog += [form['name']()]
            elif choice < 46:
                blog += [form['password']()]
            elif choice < 50:
                blog += [form['address']()]
    
        return " ".join(blog)

    def getForm(self):
        return {
            'email' : lambda : "Email: " + self.randomNumber(4) + self.randomNonProper().lower() + 
                "@" + self.randomEmailProvider() + ".com",
            'name' : lambda : "Name: " + self.randomProper() + " " + self.randomProper(),
            'password' : lambda : "Password: " + self.randomNumber(2) + self.randomNonProper() + 
                self.randomNumber(3) + self.randomProper().lower(),
            'address' : lambda : "Address: " + self.randomNumber(3) + " " + self.randomProper() + 
                " " + self.randomPostfix() + ", " + self.randomProper() + " " + self.randomState() + 
                ", " + self.randomNumber(5),
        }

words = formWords(proper, not_proper)

# %%
print words.getForm()['email']()
print words.getForm()['name']()
print words.getForm()['password']()
print words.getForm()['address']()

#This is the data variable
data = words.generateText(10000)
print data[:100]
# Out:
# Email: 1327curry@aol.com
# Name: Chicano Morrissey
# Password: 60dew612william
# Address: 924 Rockies Ave, McGill CT, 80567
# infantryman interpolatory pride Password: 56bald818harmon sticktight excise contemptible sensor code

# %% [markdown]
# ### Pull all the emails from the data variable

# %%
import re
re.findall('\w*@\w*.com', data)
# Out:
# ['9121badinage@compuserve.com',
#  '7376venture@live.com',
#  '9686chunk@yahoo.com',
#  '4496fluffy@aol.com',
#  '5685deliverance@compuserve.com',
#  '3308ostracod@compuserve.com',
#  '5619variac@compuserve.com',
#  '3781concede@aol.com',
#  '2076synonym@compuserve.com',
#  '7301become@yahoo.com',
#  '1142purgatory@aol.com',
#  '3876daffodil@yahoo.com',
#  '9035befriend@aol.com',
#  '3964brim@live.com',
#  '6481act@aol.com',
#  '2162debarring@yahoo.com',
#  '4542guanine@compuserve.com',
#  '5816crazy@aol.com',
#  '3285inhospitable@compuserve.com',
#  '4772response@yahoo.com',
#  '5275very@yahoo.com',
#  '6682lynx@compuserve.com',
#  '2734pent@compuserve.com',
#  '1664frolic@yahoo.com',
#  '3272vessel@yahoo.com',
#  '2854acquitting@live.com',
#  '1399bloodline@aol.com',
#  '2690duct@compuserve.com',
#  '7198theologian@yahoo.com',
#  '2205pecan@aol.com',
#  '9482quantitative@compuserve.com',
#  '1858disturbance@yahoo.com',
#  '2431causate@aol.com',
#  '4003antarctic@live.com',
#  '7951myopic@aol.com',
#  '5123envoy@compuserve.com',
#  '1347reb@live.com',
#  '7084chaff@yahoo.com',
#  '4446persuasion@yahoo.com',
#  '1527reticulate@aol.com',
#  '6279domesticate@live.com',
#  '8056squire@yahoo.com',
#  '4061singlet@live.com',
#  '5455benevolent@compuserve.com',
#  '5836slag@live.com',
#  '3683slippery@live.com',
#  '5681embroidery@live.com',
#  '8575cholinesterase@yahoo.com',
#  '9411abominate@yahoo.com',
#  '7606transposable@aol.com',
#  '2707longue@yahoo.com',
#  '7769status@live.com',
#  '4395notocord@compuserve.com',
#  '4255shaft@yahoo.com',
#  '2558airlock@aol.com',
#  '5163cathedral@aol.com',
#  '9257numerate@yahoo.com',
#  '1055thallium@aol.com',
#  '5671harken@aol.com',
#  '6700hay@live.com',
#  '7803adorn@compuserve.com',
#  '2674isotropy@compuserve.com',
#  '7218minicomputer@yahoo.com',
#  '1231quartile@live.com',
#  '7319horseshoe@aol.com',
#  '8823acerbic@yahoo.com',
#  '8397roundhouse@aol.com',
#  '6521dull@compuserve.com',
#  '6835afire@compuserve.com',
#  '1004graze@live.com',
#  '2565keyword@yahoo.com',
#  '4463subsidy@yahoo.com',
#  '4708headache@aol.com',
#  '6128vampire@compuserve.com',
#  '6750esophagi@compuserve.com',
#  '8776indistinguishable@yahoo.com',
#  '9118typewrite@compuserve.com',
#  '3519logistic@aol.com',
#  '7486davit@aol.com',
#  '3536roil@yahoo.com',
#  '6029steady@yahoo.com',
#  '7674merit@live.com',
#  '5685levitate@aol.com',
#  '1377happy@yahoo.com',
#  '7579marketeer@live.com',
#  '3509heifer@live.com',
#  '7976refractometer@live.com',
#  '4124giant@yahoo.com',
#  '5026intermittent@yahoo.com',
#  '5122pickle@yahoo.com',
#  '7678add@live.com',
#  '3209anonymous@aol.com',
#  '4837somewhere@live.com',
#  '3182apse@yahoo.com',
#  '1635coco@live.com',
#  '1159adhesion@live.com',
#  '3921anger@compuserve.com',
#  '3461lingo@live.com',
#  '3539psychopomp@compuserve.com',
#  '5703cultivate@yahoo.com',
#  '8961silt@compuserve.com',
#  '5061drab@compuserve.com',
#  '3081teethe@live.com',
#  '8357serape@compuserve.com',
#  '7364extradite@yahoo.com',
#  '4022silicic@compuserve.com',
#  '3238widget@yahoo.com',
#  '9806radiochemical@yahoo.com',
#  '5602original@compuserve.com',
#  '6010raccoon@yahoo.com',
#  '5198trapezoidal@compuserve.com',
#  '5984promenade@compuserve.com',
#  '1936sidesaddle@live.com',
#  '8745fumarole@live.com',
#  '9865sybarite@yahoo.com',
#  '8963calcareous@compuserve.com',
#  '9661moon@yahoo.com',
#  '8631surfactant@compuserve.com',
#  '8062oblige@yahoo.com',
#  '6580right@live.com',
#  '6862courageous@live.com',
#  '1233scuba@aol.com',
#  '3766share@yahoo.com',
#  '7094institute@compuserve.com',
#  '5130praecox@yahoo.com',
#  '6860sharecrop@compuserve.com',
#  '5297cilia@aol.com',
#  '7155hilum@live.com',
#  '4781homemade@aol.com',
#  '1293phase@aol.com',
#  '9153homeland@compuserve.com',
#  '3003literature@compuserve.com',
#  '7633nuance@aol.com',
#  '6992plait@live.com',
#  '1098chloroplast@yahoo.com',
#  '1997pater@compuserve.com',
#  '2804beard@live.com',
#  '1521pappy@live.com',
#  '3711eke@compuserve.com',
#  '8710appellant@live.com',
#  '9148erode@compuserve.com',
#  '1316principle@aol.com',
#  '1999leprosy@compuserve.com',
#  '9271craftsperson@aol.com',
#  '6228absenteeism@live.com',
#  '4759cockle@yahoo.com',
#  '8874biota@aol.com',
#  '1934him@compuserve.com',
#  '7361frown@yahoo.com',
#  '2848bathtub@yahoo.com',
#  '6398fugitive@yahoo.com',
#  '8054airdrop@live.com',
#  '9114factual@aol.com',
#  '1828hero@live.com',
#  '9983chatty@aol.com',
#  '4335came@yahoo.com',
#  '5491avoidance@yahoo.com',
#  '1123notoriety@compuserve.com',
#  '8259diathermy@yahoo.com',
#  '8747auspices@compuserve.com',
#  '9739compromise@compuserve.com',
#  '3041proficient@live.com',
#  '7599paint@aol.com',
#  '3209halve@live.com',
#  '3898trailblazing@aol.com',
#  '6636emcee@aol.com',
#  '2662diminutive@live.com',
#  '8265decode@aol.com',
#  '6419doberman@live.com',
#  '4410complacent@aol.com',
#  '2633antigen@compuserve.com',
#  '1663guidance@aol.com',
#  '8865circa@compuserve.com',
#  '5187rajah@yahoo.com',
#  '6392toluene@live.com',
#  '6324jerry@yahoo.com',
#  '6700response@compuserve.com',
#  '6312admiralty@yahoo.com',
#  '4616psyche@live.com',
#  '7767thistle@aol.com',
#  '3065why@yahoo.com',
#  '9125sept@yahoo.com',
#  '6949annal@yahoo.com',
#  '2301inheritance@yahoo.com',
#  '8249accountant@compuserve.com',
#  '9456motif@yahoo.com',
#  '2643conformal@live.com',
#  '5960liberty@compuserve.com',
#  '6699spellbound@compuserve.com',
#  '8029grape@aol.com',
#  '1297refrain@live.com',
#  '7775preach@aol.com',
#  '7749tantamount@compuserve.com',
#  '6442trait@live.com',
#  '1228gainful@compuserve.com',
#  '4034horrid@aol.com',
#  '3496mortuary@yahoo.com',
#  '1114ion@compuserve.com',
#  '9862ginger@yahoo.com',
#  '1114contend@compuserve.com',
#  '9616dowel@aol.com',
#  '4613trial@live.com',
#  '1317impartial@compuserve.com',
#  '7750insurmountable@aol.com',
#  '2764empiric@compuserve.com',
#  '4038omnivorous@compuserve.com',
#  '1881earnest@compuserve.com',
#  '5410shovel@yahoo.com',
#  '9473sabra@aol.com',
#  '8827prosecution@compuserve.com',
#  '2925licensor@compuserve.com',
#  '5966variant@yahoo.com',
#  '9313alloy@aol.com',
#  '8751backside@aol.com',
#  '5181incubi@compuserve.com',
#  '6246attention@yahoo.com',
#  '1417caching@yahoo.com',
#  '7122swallowtail@live.com',
#  '1799byproduct@compuserve.com',
#  '9179runoff@yahoo.com',
#  '1733papa@compuserve.com',
#  '4135toe@aol.com',
#  '4110gangplank@compuserve.com',
#  '1618tickle@compuserve.com',
#  '7451borderline@compuserve.com',
#  '9584eclogue@aol.com',
#  '6249stir@aol.com',
#  '8187much@aol.com',
#  '3027vestigial@compuserve.com',
#  '8276barter@yahoo.com',
#  '4379autocorrelate@compuserve.com',
#  '1431today@aol.com',
#  '5492rosary@aol.com',
#  '1972literate@yahoo.com',
#  '1784uttermost@live.com',
#  '8595lysergic@yahoo.com',
#  '1073strange@compuserve.com',
#  '8832drainage@live.com',
#  '8883bulblet@compuserve.com',
#  '6756virulent@yahoo.com',
#  '9779cowpony@yahoo.com',
#  '8619parch@yahoo.com',
#  '5874lanthanum@compuserve.com',
#  '3522remnant@yahoo.com',
#  '7512bombproof@live.com',
#  '1273spearhead@aol.com',
#  '2784abscissa@yahoo.com',
#  '1787twelfth@compuserve.com',
#  '4715spheric@live.com',
#  '4142tungstate@live.com',
#  '1182bronco@compuserve.com',
#  '2931begrudge@live.com',
#  '1086quagmire@yahoo.com',
#  '6265bagging@yahoo.com',
#  '6231golf@live.com',
#  '5112penthouse@yahoo.com',
#  '7179battlefront@live.com',
#  '3350oratoric@aol.com',
#  '7203licensee@yahoo.com',
#  '9519clogging@aol.com',
#  '7883hebephrenic@yahoo.com',
#  '9489toss@live.com',
#  '1412bookbind@live.com',
#  '4182faithful@live.com',
#  '9574specious@yahoo.com',
#  '1451spurious@live.com',
#  '5355treasure@compuserve.com',
#  '6804masque@live.com',
#  '9927truth@aol.com',
#  '2420custodial@live.com',
#  '8174quod@yahoo.com',
#  '8739sponge@live.com',
#  '9424inspect@yahoo.com',
#  '3553dickey@live.com',
#  '9464track@yahoo.com',
#  '6697archae@live.com',
#  '2478aftereffect@compuserve.com',
#  '6578shiny@compuserve.com',
#  '8929bawd@live.com',
#  '4713leather@aol.com',
#  '8943skater@aol.com',
#  '2402node@live.com',
#  '6301employ@compuserve.com',
#  '7335mooch@compuserve.com',
#  '9011cetera@live.com',
#  '6616retardant@compuserve.com',
#  '8961guideline@yahoo.com',
#  '2645substituent@yahoo.com',
#  '1730fruitful@aol.com',
#  '9044seaport@live.com',
#  '7128kept@live.com',
#  '8729workspace@compuserve.com',
#  '3539far@yahoo.com',
#  '2132suave@yahoo.com',
#  '8884retrogress@aol.com',
#  '3462diphtheria@compuserve.com',
#  '4302concubine@live.com',
#  '2485teeth@live.com',
#  '8670holography@yahoo.com',
#  '3541bowel@yahoo.com',
#  '9032coloratura@compuserve.com',
#  '8018shelter@compuserve.com',
#  '1017taiga@live.com',
#  '5542ornithology@yahoo.com',
#  '5551walkie@aol.com',
#  '7711wrought@compuserve.com',
#  '2187gatekeeper@yahoo.com',
#  '2245orgasm@live.com',
#  '8878gain@compuserve.com',
#  '8274aside@compuserve.com',
#  '1554thaw@live.com',
#  '2384seldom@yahoo.com',
#  '8242callosity@yahoo.com',
#  '5392it@aol.com',
#  '7896photography@compuserve.com',
#  '8914debonair@aol.com',
#  '9674hypotheses@compuserve.com',
#  '1139penumbral@yahoo.com',
#  '4490idyllic@compuserve.com',
#  '2228prorogue@yahoo.com',
#  '7899usual@compuserve.com',
#  '3006gneiss@compuserve.com',
#  '1719diaphanous@aol.com',
#  '4853obedient@live.com',
#  '1457biology@compuserve.com',
#  '2182volcanism@live.com',
#  '9019try@yahoo.com',
#  '6410troy@yahoo.com',
#  '4582factious@live.com',
#  '8693replete@live.com',
#  '6713suspicion@live.com',
#  '9296silk@yahoo.com',
#  '9081shopworn@yahoo.com',
#  '8996amoral@compuserve.com',
#  '5681wraith@compuserve.com',
#  '4734cathodic@yahoo.com',
#  '6914concertmaster@live.com',
#  '8536casino@yahoo.com',
#  '7645special@compuserve.com',
#  '9286sprocket@compuserve.com',
#  '9138mileage@live.com',
#  '9084hindquarters@live.com',
#  '4319yield@live.com',
#  '9735flesh@aol.com',
#  '5127heartfelt@compuserve.com',
#  '4326soon@compuserve.com',
#  '1108oneself@live.com',
#  '1241bidden@yahoo.com',
#  '9058sandbag@yahoo.com',
#  '5389sorrow@live.com',
#  '9100pirouette@yahoo.com',
#  '8976radiotherapy@compuserve.com',
#  '6879intra@aol.com',
#  '5467anther@aol.com',
#  '5721frizzle@live.com',
#  '2581wicket@aol.com',
#  '3377covetous@live.com',
#  '5433accipiter@yahoo.com',
#  '3631field@aol.com',
#  '7768pave@compuserve.com',
#  '1120convolution@yahoo.com',
#  '7109augite@compuserve.com',
#  '8218epidemiology@live.com',
#  '6885ejaculate@live.com',
#  '4307magnanimity@aol.com',
#  '6533convince@yahoo.com',
#  '1816boron@live.com',
#  '9690improbable@yahoo.com',
#  '7675ethylene@yahoo.com',
#  '7379gunman@live.com',
#  '7961conservation@compuserve.com',
#  '7228ahoy@compuserve.com',
#  '8461contraband@compuserve.com',
#  '4436dairy@live.com',
#  '7025glyph@yahoo.com',
#  '5195radon@aol.com',
#  '1902garner@aol.com',
#  '4075congest@aol.com',
#  '5650midrange@yahoo.com',
#  '4465laid@aol.com',
#  '4193linguist@yahoo.com',
#  '4287crore@yahoo.com',
#  '3787size@compuserve.com',
#  '4395peripatetic@compuserve.com',
#  '6136qualm@aol.com',
#  '8183barbecue@aol.com',
#  '4388one@compuserve.com',
#  '3584flip@aol.com',
#  '7413belove@aol.com',
#  '1747deltoid@live.com',
#  '2682subtrahend@aol.com',
#  '8226stodgy@compuserve.com',
#  '7778succinct@compuserve.com',
#  '2504sabbatical@yahoo.com',
#  '4938devote@yahoo.com',
#  '8045comprise@aol.com',
#  '3844tyrannic@live.com',
#  '7483bonus@yahoo.com',
#  '7193tacky@aol.com',
#  '7948glyph@compuserve.com',
#  '4024amok@aol.com',
#  '7251alight@aol.com',
#  '2216stud@aol.com',
#  '1318evade@live.com',
#  '8645dumb@yahoo.com',
#  '8905silversmith@compuserve.com',
#  '1916abeyant@compuserve.com',
#  '7577retroactive@yahoo.com',
#  '7283bend@aol.com',
#  '6995colatitude@aol.com',
#  '8015scripture@live.com',
#  '4611epigram@aol.com',
#  '5006dehumidify@compuserve.com',
#  '8018lament@aol.com',
#  '3285frambesia@yahoo.com',
#  '9097puzzle@aol.com',
#  '6591extremum@aol.com',
#  '1852canister@aol.com',
#  '5923impudent@live.com',
#  '7621egocentric@live.com',
#  '3941blank@live.com',
#  '8458yeomen@live.com',
#  '6881ethnic@aol.com',
#  '9477sneaky@yahoo.com',
#  '9657spin@live.com']

# %% [markdown]
# ### Pull all the names from the data variable

# %%
re.findall('Name:\s(\w*\s+\w*)', data)
# Out:
# ['Hegelian Feb',
#  'Cantabrigian Leander',
#  'Lebanese Aida',
#  'Riley Algiers',
#  'Katie Nyquist',
#  'Ludwig Kline',
#  'Jon NRC',
#  'Hubbard Delphinus',
#  'Delphi Socrates',
#  'Orphic Crawford',
#  'Pinsky Bizet',
#  'Sterno Dreyfuss',
#  'Byrne Sheridan',
#  'Cyrillic Kingsbury',
#  'Teledyne IA',
#  'Boeing Donner',
#  'Henrietta Weyerhauser',
#  'Knickerbocker Latrobe',
#  'Durrell Varian',
#  'Aegean Kelsey',
#  'Europe Hancock',
#  'Fargo Malagasy',
#  'Gwyn Brooklyn',
#  'Bernhard Albert',
#  'Burnham Saxon',
#  'Odin Levis',
#  'Tom Mindanao',
#  'Lucifer Miguel',
#  'Harris Lancelot',
#  'Floridian Dickerson',
#  'Terre Antioch',
#  'Becky Alabama',
#  'Ellwood Paulette',
#  'Argus Levis',
#  'Crosby Constantinople',
#  'Ilyushin FMC',
#  'Robinson Xavier',
#  'Wilkins Joshua',
#  'Saul Sussex',
#  'Byrne Macbeth',
#  'Oneida Maurine',
#  'Delaney Lydia',
#  'Galatea Prokofieff',
#  'Angus Susanne',
#  'Amman Yorkshire',
#  'Sherlock TOEFL',
#  'Hilbert Niobe',
#  'Harcourt AL',
#  'Boreas Rooseveltian',
#  'Chiang Ainu',
#  'Dnieper Shirley',
#  'Sophocles Cerberus',
#  'Berglund Kelsey',
#  'Erickson Bundoora',
#  'Ephraim Alsop',
#  'Rhine Kilimanjaro',
#  'Sicily Jewett',
#  'Kiowa Sagittarius',
#  'Lodowick Runyon',
#  'French Lucille',
#  'Ike Fairchild',
#  'Elmer Whalen',
#  'Leopold Gino',
#  'Cooley Greenland',
#  'Kieffer Galapagos',
#  'Hades Paulus',
#  'Olga Sonora',
#  'Daedalus Lindholm',
#  'Clinton Miles',
#  'Mesopotamia Dallas',
#  'Des Chen',
#  'Brahms Stromberg',
#  'FAA David',
#  'Kuwait Ripley',
#  'Dana Helena',
#  'Houdini McDonnell',
#  'Dahl Brahmsian',
#  'Laredo Knutson',
#  'Igor Irving',
#  'Uganda Crispin',
#  'Doria Arcadia',
#  'Ethan Dow',
#  'Mycenae Heinz',
#  'Nadine Ligget',
#  'Montclair Heisenberg',
#  'Bhutan Wendell',
#  'Posner McGill',
#  'Burgundy Edwardine',
#  'Porte TTY',
#  'Mitchell Islamic',
#  'Acadia Wolff',
#  'Medusa Melvin',
#  'Ridgway Montreal',
#  'Athens NOAA',
#  'Firestone Beaujolais',
#  'Zeiss Frances',
#  'Fafnir Salish',
#  'Goethe Babylon',
#  'Abo Billie',
#  'Anastasia Helga',
#  'Riordan Santiago',
#  'Cody Wabash',
#  'Quinn Spica',
#  'Hiroshima Otis',
#  'Alfred Katmandu',
#  'Knauer Hendrickson',
#  'Hausdorff Presbyterian',
#  'Gestapo Malay',
#  'French Wheller',
#  'Lester Klein',
#  'Malton FDA',
#  'Sony Faustus',
#  'Priam Meg',
#  'Lana Darwinian',
#  'Cortez Henri',
#  'Storey Dixon',
#  'Josephine Bayda',
#  'Persephone McDowell',
#  'Hanover Moldavia',
#  'Appalachia Waldo',
#  'Wendy Zimmerman',
#  'Yvette Kashmir',
#  'Hyman Delft',
#  'Trobriand Whittaker',
#  'Gustafson Watanabe',
#  'Luxembourg Duluth',
#  'Stauffer Sterno',
#  'Confucian Bonaventure',
#  'Dutton Nineveh',
#  'Hungary Barnard',
#  'Schofield Micronesia',
#  'Scottish Stonehenge',
#  'Antony Litton',
#  'Antilles Giacomo',
#  'Crestview Whitney',
#  'ERDA Oberlin',
#  'Saudi Sargent',
#  'Cumberland Io',
#  'Garfield Calkins',
#  'Magellanic Kellogg',
#  'Bailey Waterman',
#  'SC Hickey',
#  'Utrecht Navajo',
#  'Akron Canaveral',
#  'Duncan Stegosaurus',
#  'Harris Alfred',
#  'Baden Hecate',
#  'Vikram Raymond',
#  'Natchez Gerard',
#  'Bauhaus Istvan',
#  'Ludlow Huggins',
#  'Donahue MacDougall',
#  'Dwight Ethan',
#  'Barrymore Shawnee',
#  'Sana Punic',
#  'Annette Saudi',
#  'Elba April',
#  'Marcello Hinman',
#  'Loomis Eurydice',
#  'Sana Ashmolean',
#  'Banach Ku',
#  'Hendrickson Wyandotte',
#  'Gilligan Warburton',
#  'Beethoven Georgia',
#  'Hausdorff Ashmolean',
#  'Pavlov Mercator',
#  'Thornton British',
#  'Pakistani FL',
#  'Hoff Angie',
#  'Canada Chen',
#  'Grimaldi Comanche',
#  'Bradshaw Henri',
#  'Tarbell Chartres',
#  'Daly Jennie',
#  'Haitian Eurydice',
#  'Enrico Nazism',
#  'Vermont Rooseveltian',
#  'Osborne Punjab',
#  'Jr Westminster',
#  'Keith Ezekiel',
#  'Dorado Nicholls',
#  'SE Liverpool',
#  'Vance Salisbury',
#  'FIFO Parsifal',
#  'Rwanda Asia',
#  'Mogadiscio Armenia',
#  'Lorinda Leon',
#  'Marjorie Pavlov',
#  'Muscovy Chopin',
#  'Glaswegian Thomas',
#  'Banbury NIMH',
#  'Lyle Bujumbura',
#  'Palo Ramo',
#  'Orion Schulz',
#  'Whippany Suzanne',
#  'Selfridge Groton',
#  'Whittaker Nan',
#  'Alberto Doolittle',
#  'Abramson Goodman',
#  'Anthony Dora',
#  'Seymour Nicaragua',
#  'Herbert Hawkins',
#  'Tuscaloosa Ruanda',
#  'Pericles Dearborn',
#  'Devonshire Alger',
#  'Clytemnestra Napoleon',
#  'Isolde McCabe',
#  'Asher Cadillac',
#  'Bonneville Gustav',
#  'Anglophobia Kabul',
#  'Monteverdi Laramie',
#  'Graff Cain',
#  'Brandt Atropos',
#  'Jacobite Yorktown',
#  'Leibniz Sunday',
#  'Yakima Nolan',
#  'Eumenides Cominform',
#  'Helen Northrup',
#  'Charybdis Managua',
#  'Kannada Hecate',
#  'Dumpty Hammond',
#  'Calvert Sheppard',
#  'Egyptian Irving',
#  'Tuesday Holyoke',
#  'Potomac Capetown',
#  'Shirley Ronald',
#  'Lindsay Coffey',
#  'Bruegel Geoffrey',
#  'NV Springfield',
#  'Salvador Bernardino',
#  'Pinsky Rinehart',
#  'McClain Titan',
#  'Deborah Waals',
#  'Evanston Dionysian',
#  'Kermit Jakarta',
#  'Waldron Waals',
#  'Bogota Wilfred',
#  'Pusey Kaplan',
#  'Gloria Butterfield',
#  'Abernathy Balfour',
#  'Ericsson Hastings',
#  'Montclair Chungking',
#  'Goodwin Waite',
#  'Curran Barnet',
#  'Kenneth Jupiter',
#  'Cobol Schlesinger',
#  'Mazda Elsie',
#  'Nicodemus MO',
#  'Compagnie Brighton',
#  'Leroy Andover',
#  'Lura McGinnis',
#  'Schubert Italian',
#  'Stevenson Drummond',
#  'Breton Cushing',
#  'MBA Smucker',
#  'Frye Demeter',
#  'Antares Carbone',
#  'McLeod Piotr',
#  'Lodowick Brontosaurus',
#  'Kurd VT',
#  'Charybdis Charley',
#  'Ellen Ryder',
#  'Dubhe Constantinople',
#  'Lounsbury Bergland',
#  'Lamar Banach',
#  'Raman Dempsey',
#  'Moore Blvd',
#  'Mildred February',
#  'Bridgewater Markovian',
#  'Chinatown TOEFL',
#  'Wittgenstein Gottfried',
#  'Egypt Gothic',
#  'Kochab Fleming',
#  'Dalhousie Ghana',
#  'Elaine Emery',
#  'Andrea Dominique',
#  'Epicurean Swarthout',
#  'Cardiff Rowley',
#  'Merritt Sci',
#  'Compton Durango',
#  'Belgrade Dalzell',
#  'Dominick Recife',
#  'Elmira Gil',
#  'Knoxville Tigris',
#  'Lubbock Manchester',
#  'Klein Hillel',
#  'Cosgrove Orca',
#  'PDP Herschel',
#  'Beaumont Ernie',
#  'Rudy Sikkim',
#  'Brumidi Bosporus',
#  'GPO Hershey',
#  'Chinook Jackson',
#  'Mackinac Monroe',
#  'Palatine PhD',
#  'Lockhart Marty',
#  'Sumter Allstate',
#  'Afghanistan Boylston',
#  'Chandigarh Arlen',
#  'Morocco Latrobe',
#  'Hatteras R',
#  'Hiram Coronado',
#  'Yeats John',
#  'Carlisle Marriott',
#  'Orpheus Vernon',
#  'Columbus Wehr',
#  'Lear Castro',
#  'Wylie Pyrex',
#  'Lacerta Jed',
#  'Lucretia Sumeria',
#  'Barnabas Mbabane',
#  'Menzies Grimm',
#  'Emory Hayes',
#  'Earthman Dougherty',
#  'Minnesota Raritan',
#  'Welles Minerva',
#  'Antietam Lloyd',
#  'Kipling Zachary',
#  'Vivaldi Nordhoff',
#  'Nyquist Gifford',
#  'Goa Brandt',
#  'Dwyer Copernicus',
#  'Jed Blackburn',
#  'Hopi Penn',
#  'Chantilly Boucher',
#  'Puerto Czerniak',
#  'Martinique Middletown',
#  'Roland Hanford',
#  'Ramsey Almaden',
#  'Harriet Somerset',
#  'Dunn Alhambra',
#  'Hereford Hopi',
#  'Granville Vladivostok',
#  'Ghana Nicosia',
#  'Waals Sunday',
#  'Dobbs Crandall',
#  'Czechoslovakia Spector',
#  'Vance Kramer',
#  'Barrymore Selectric',
#  'Christoffel Sargent',
#  'Bolshoi Gerry',
#  'Lisbon Krause',
#  'Dortmund Protozoa',
#  'Politburo O',
#  'Selena Sigmund',
#  'Rufus Bangladesh',
#  'Illinois December',
#  'Matthew Ganymede',
#  'Bingham Atropos',
#  'Conant Blackwell',
#  'Indoeuropean Posner',
#  'BP Ramada',
#  'Carr Sullivan',
#  'Compagnie Parsifal',
#  'Justinian Brian',
#  'Shakespearian Shasta',
#  'Latrobe Madeira',
#  'Levitt Mathias',
#  'Zen Warsaw',
#  'Knauer Nguyen',
#  'Whelan Nair',
#  'Neil Catskill',
#  'Howell NATO',
#  'Mullen Telex',
#  'Dietz IA',
#  'Bernadine Afghanistan',
#  'Bryn Andalusia',
#  'Mirfak Irene',
#  'Olympic Hatfield',
#  'Russ Baja',
#  'Leeds Bailey',
#  'Manhattan Epsom',
#  'Etruscan Rube',
#  'Rosenblum Estes',
#  'Sorensen France',
#  'Kinney Germany',
#  'Waldo Hinman',
#  'Debby Sarasota',
#  'Hatfield Rhode',
#  'Durham Recife',
#  'Passover Lehigh',
#  'Radcliffe Weinberg',
#  'Kathy Ghent',
#  'Lysenko Ursuline',
#  'Ann Rutland',
#  'Teresa Evans',
#  'Amos Robertson',
#  'Nielson Camembert',
#  'Mobil Alcmena',
#  'Liz Rowe',
#  'Sonora Jonas',
#  'McMillan Labrador',
#  'Waring December',
#  'Monteverdi Omaha',
#  'Paulson Portia',
#  'Sumeria Foley',
#  'Clarke Woodbury',
#  'Eleanor Renault',
#  'Budd Danish',
#  'Stapleton Shulman',
#  'Tokyo Scotia',
#  'Gruyere Scorpio',
#  'Shawnee Stewart',
#  'Burr Dana',
#  'MacGregor Canaan',
#  'Gino MacMillan',
#  'Spiegel Mediterranean',
#  'Mooney Canterbury',
#  'Rebecca Philippine',
#  'Scythia Saran',
#  'Kong Eagan',
#  'Strickland Fresno',
#  'Tiber Arkansas',
#  'Amerada Dave',
#  'Bernstein Amman',
#  'Westchester Ceres',
#  'Francoise Maxwellian',
#  'Burmese Stonehenge',
#  'Somalia Celtic',
#  'Aleck Bolshevik',
#  'Hathaway Randall',
#  'Sistine Castro',
#  'Quakeress Klein',
#  'Hawley Lars',
#  'Sumatra Camden',
#  'Hesperus Christianson',
#  'Dodson Corcoran',
#  'Pecos Calgary',
#  'Aristotle Wilson',
#  'Munson Libya',
#  'Igor Norwich',
#  'Raphael Frankel',
#  'Melinda McKee',
#  'Orin Rockies',
#  'Nabisco Nazi',
#  'Claire Kodachrome',
#  'Ulster Albright',
#  'Moser Bakhtiari',
#  'Amelia Oct',
#  'Beardsley Atwater',
#  'Edmonton Gaston',
#  'Bamberger Euphrates',
#  'Vandenberg Abelson',
#  'English Noll',
#  'Abelian Peking',
#  'Keyes Gestapo',
#  'Chopin Alberich',
#  'Littleton FPC',
#  'USC Rickettsia',
#  'European London',
#  'Simla Harmon',
#  'Gifford Proserpine',
#  'Fallopian Glenn',
#  'McFarland Pius',
#  'Paraguay BSTJ',
#  'Hades Janice',
#  'Adlerian NH',
#  'Antwerp Samuelson',
#  'Nippon Marilyn',
#  'Minnesota Ghent',
#  'Honshu Silas',
#  'Jorgenson Westchester',
#  'Uranus Onondaga',
#  'Formica Doyle',
#  'Sylvester Sharpe',
#  'Israeli Algonquin',
#  'Ektachrome Fuchsia',
#  'Persephone Bobbie',
#  'Chaplin Jordan',
#  'Berman Pfizer',
#  'Anaheim Bobbie',
#  'Celtic Cohn',
#  'Abraham Roy',
#  'Panamanian Andrea',
#  'Brunswick Delilah',
#  'Eugenia Stuyvesant',
#  'Tuscarora Juneau',
#  'Verlag Carr',
#  'Grumman Olaf',
#  'Eldon Pandora',
#  'Fallopian Quichua',
#  'Capricorn Weierstrass',
#  'NATO Hague',
#  'Sylvania Matson',
#  'Brookhaven Barnard',
#  'Orlando Mellon',
#  'Niamey Spector',
#  'Bryn Rube',
#  'Gino Cenozoic',
#  'Georgia Pius',
#  'Monica Larson',
#  'Runyon Holocene',
#  'Cowan Keaton',
#  'Ada YMCA',
#  'Slavonic Rosenberg',
#  'Abe Hippocratic',
#  'Susie Lipschitz',
#  'Ecole Venetian',
#  'Patsy Marguerite',
#  'Costello Dailey',
#  'Mathias Lobelia',
#  'Elijah Josephine',
#  'Friesland McGee',
#  'Isfahan Shapiro',
#  'Boston Hal',
#  'McAllister Mexico',
#  'Fahrenheit Vaughan',
#  'Mayfair Java',
#  'Lorenz Dacca',
#  'Muir Pugh',
#  'Morocco Phelps',
#  'Lev Diego',
#  'Rosalie Perkins',
#  'Kennan Aeneid',
#  'Atchison Auckland',
#  'Nairobi Conner',
#  'Dacca Goldman',
#  'Arcadia Hadley',
#  'Cambridge Susie',
#  'BP Alice',
#  'Dusenberg Yellowstone',
#  'Northumberland Lenore',
#  'Brie Dryden',
#  'Bundestag Clive',
#  'Walpole Zoe',
#  'Columbus Seville',
#  'Fuji Doric',
#  'Nostradamus Lenten',
#  'Wilmington Derbyshire',
#  'Kankakee Hinman',
#  'Siemens Ulster',
#  'Zagreb Janus',
#  'FAA Berniece',
#  'Yiddish Lorenz',
#  'NBS Heuser',
#  'Andorra Byron',
#  'Nicaragua Cyprus',
#  'Fogarty Winslow',
#  'Cyprus Heathkit',
#  'Lavoisier Samuelson',
#  'Fraser Goldwater',
#  'Kruger Adonis',
#  'Fred MD',
#  'Randall Kigali',
#  'Delft Wallace',
#  'Marx Cretan',
#  'Callahan Crockett',
#  'Phoenicia PepsiCo',
#  'Yankton Storey',
#  'Malawi McGowan',
#  'McKee Icarus',
#  'Clara Abidjan',
#  'Haynes Theseus',
#  'Regulus Bingham',
#  'Tarbell Mogadiscio',
#  'Baylor Waller',
#  'Fredericksburg Hayden',
#  'Ramo Simonson',
#  'Knickerbocker Grimm',
#  'Herculean Teledyne',
#  'Notre Mao',
#  'Kaufman Edmonton',
#  'Patagonia Carthage',
#  'Seminole Afrikaner',
#  'Dolan Byron',
#  'Hanoi SC',
#  'Transvaal Sunday',
#  'Bruce Andy',
#  'BP Jacobi',
#  'Atlantis Mr',
#  'Muskegon Jenkins',
#  'EPA Ayers',
#  'Egyptian Nicaragua',
#  'Aladdin Sussex',
#  'Spencer Lehman',
#  'Baku Farmington',
#  'Maximilian Vaughn',
#  'Cepheus Winchester',
#  'Mona Tarzan',
#  'Glaswegian Sheridan',
#  'Bantus Gertrude',
#  'Malraux Fran',
#  'Ares Scot',
#  'Irvine Hermann',
#  'Hines Poseidon',
#  'Canadian Choctaw',
#  'Ed FAA',
#  'Phelps Salish',
#  'Bundoora Titan',
#  'Eccles Jakarta',
#  'Cody Nagy',
#  'Hirsch Seneca',
#  'Schuster Diogenes',
#  'Biggs Kurt',
#  'Holyoke Hancock',
#  'Lise Walt',
#  'Missouri Brunhilde',
#  'CUNY Thea',
#  'Conestoga Katz',
#  'Churchill PepsiCo',
#  'Annette Wahl',
#  'Penh Siemens',
#  'Getty Gaylord',
#  'Medford St',
#  'Kowloon Hankel',
#  'Alexandria Brahmsian',
#  'Seoul Hendrick',
#  'Atreus Lockhart',
#  'Agatha Barnett',
#  'Hearst Alexandra',
#  'Bagley Dylan',
#  'Shylock Jordan',
#  'Vernon Argentina',
#  'NBC Bourbaki',
#  'Hempstead Bonaparte',
#  'Piotr Eleazar',
#  'Alamo Snyder',
#  'Keller Clausen',
#  'McCormick Mycenaean',
#  'Bantus Buchwald',
#  'Cabot Cynthia',
#  'Hildebrand Shirley',
#  'Mahayanist Trastevere',
#  'Croatia Kochab',
#  'Chattanooga Gresham',
#  'Lancelot NW',
#  'Fairfax Stuyvesant',
#  'Rudy Holloway',
#  'Wheller Allstate',
#  'Mesozoic DuPont',
#  'Memphis Daly',
#  'Hoagland Benares',
#  'Wei Johannes',
#  'Juno Aviv',
#  'Chomsky Everglade',
#  'Veneto Urdu',
#  'Ms Kilimanjaro',
#  'Bausch Swaziland',
#  'Dutton Aquarius',
#  'Texaco Minneapolis',
#  'Seton Eskimo',
#  'Telex Richfield',
#  'Ottoman Rockford',
#  'Thompson Friedman',
#  'LIFO Pepsi',
#  'Gallagher Russell',
#  'TA Caldwell',
#  'SSW Lenore',
#  'Barbara Paraguay',
#  'Garvey Montenegrin',
#  'Carnegie Genesco',
#  'Harvard Lisbon',
#  'Hamburg Foley',
#  'Dan Shaffer',
#  'Tennessee McNeil',
#  'Andersen America',
#  'Pericles Ira',
#  'Swaziland Winthrop',
#  'Grady Plato',
#  'Egyptology Brest',
#  'Chablis Legendre',
#  'McDermott Cramer',
#  'Guggenheim Drury',
#  'McKay Pyongyang',
#  'Hindustan Elmsford',
#  'Clara Ferrer',
#  'Jugoslavia Ekstrom',
#  'Russ Vienna',
#  'Elliott Convair',
#  'Thermofax I',
#  'Gilead Jessica',
#  'Andrei Fresno',
#  'Pamela Yellowknife',
#  'Galilee Monoceros',
#  'Ptolemaic Slovenia',
#  'Amerada Erik',
#  'Thomson Lucille',
#  'Monongahela Claremont',
#  'Custer Galbreath',
#  'Moll McHugh',
#  'Japanese Alpert',
#  'Goethe Vladimir',
#  'Joanne PhD',
#  'Farmington Haugen',
#  'Irving Pauli',
#  'Mongolia Gauguin',
#  'Ellsworth Jed',
#  'Godfrey Gibson',
#  'Lutheran Humboldt',
#  'Falmouth Emil',
#  'NYU Mesopotamia',
#  'Nicaragua Savoyard',
#  'Wyatt Mohawk',
#  'Harrison Celtic',
#  'Bundestag Locke',
#  'Abraham Roth',
#  'Thor Claude',
#  'Brownian Hardin',
#  'RI Sachs',
#  'Aruba Montana',
#  'Santiago Myron',
#  'Thai Klaus',
#  'Wheatstone Sullivan',
#  'Wilkes Hewitt',
#  'Pulitzer Mullen',
#  'Tacitus Silverman',
#  'Pasadena Gaelic',
#  'Kernighan Antaeus',
#  'Ojibwa Jovian',
#  'Kampala Recife',
#  'PDP Morrissey',
#  'Champlain Zeus',
#  'Sullivan Beckman',
#  'Willa Hanley',
#  'Bakelite Ising',
#  'Heraclitus Caribbean',
#  'Dorothea LTV',
#  'Compagnie Manley',
#  'Kamchatka Brooklyn',
#  'Altair Leila',
#  'Matilda Pullman',
#  'Dorothea Bennett',
#  'Leander Vatican',
#  'Genoa Suzuki',
#  'Shu Peale',
#  'Harold Missouri',
#  'Liz Collins',
#  'Knott Ottawa',
#  'Chadwick Joaquin',
#  'Sinai Spaulding',
#  'BSTJ McKeon',
#  'Nottingham Beltsville',
#  'Holstein Amarillo',
#  'Eliot Accra',
#  'Hebrides Vera',
#  'YWCA Omaha',
#  'Dempsey Sistine',
#  'Heidelberg Yeats',
#  'Ron Manitoba',
#  'Mesozoic SST',
#  'Arkansan Rumania',
#  'CIA Auschwitz',
#  'Irrawaddy Holman',
#  'Goodyear Cairo',
#  'Ferguson Ramada',
#  'Bertha Diane',
#  'Geoffrey Neva',
#  'Palomar Hades',
#  'Worcestershire FMC',
#  'Lovelace Dickson',
#  'Hamburg Talmudic',
#  'Wappinger Lancashire',
#  'Adriatic Dudley',
#  'Cynthia Xhosa',
#  'Sunnyvale Angora',
#  'Cody Euclidean',
#  'Buttrick Palo',
#  'Kigali Liverpudlian',
#  'Amerada Ypsilanti',
#  'Manama Volvo',
#  'Periclean Huxley',
#  'Poynting Wilkes',
#  'Galbreath WECo',
#  'Ulan Wilmington',
#  'Aquila Kim',
#  'Medford Caesar',
#  'Mont Greenblatt',
#  'Tarbell Aeneid',
#  'Niamey Marcy',
#  'Fisk Argonne',
#  'Rudy Gimbel',
#  'Krakow Pythagoras',
#  'Gaulle Severn',
#  'Hanoverian Andrew',
#  'Cohn Kochab',
#  'Johnsen Aubrey',
#  'BP Burnham',
#  'Dodd Moldavia',
#  'Weyerhauser Fairchild',
#  'Fairfield Chandigarh',
#  'Hagen Hebrew',
#  'Valkyrie Madonna',
#  'Libya Oppenheimer',
#  'Lehman Santiago',
#  'Deborah Czerniak',
#  'Deanna Kalamazoo',
#  'Jamestown Cajun',
#  'Nazism NBC',
#  'POBox Della',
#  'Bernstein Monrovia',
#  'Loki Ike',
#  'Schoenberg Steiner',
#  'Jaime Araby',
#  'Vail Kalamazoo',
#  'EEOC Cretan',
#  'Canoga Gaylord',
#  'Jamaica Richfield',
#  'Maggie Broglie',
#  'Pyongyang Mediterranean',
#  'Angus Buddha',
#  'Lilian Turkish',
#  'Marrietta Blackfeet',
#  'Bertie Whittier',
#  'Capitoline Ron',
#  'Natchez Prescott',
#  'Gwen Bangladesh',
#  'Cartesian Gibraltar',
#  'Moe Uniroyal',
#  'Bristol Brennan',
#  'Braniff EST',
#  'Schottky Brontosaurus',
#  'Auschwitz Minos',
#  'Hankel Ibn',
#  'Gideon Salerno',
#  'Spiro Buchanan',
#  'Jungian Mycenae',
#  'Lomb Elmhurst',
#  'Andrea Bathurst',
#  'Caine Ajax',
#  'Ganges San',
#  'Romulus Tommie',
#  'Chapman AL',
#  'Fiberglas Werner',
#  'Andy Hodges',
#  'Mafioso Duluth',
#  'Windsor Malta',
#  'Malthus Pretoria',
#  'Howell NC',
#  'KY Lombard',
#  'Purina Palo',
#  'Capitoline Minerva',
#  'Voss Giuliano',
#  'CERN Holmes',
#  'Ackerman Delhi',
#  'Romanesque Edmondson']

# %% [markdown]
# ### Pull all the passwords from the data variable

# %%
re.findall('Password:\s(\w*)', data)
# Out:
# ['25elastomer864krebs',
#  '54fosterite120emery',
#  '39inactive325phd',
#  '83bellwether753argentinian',
#  '97oblate162whitcomb',
#  '83spokesmen164gordon',
#  '60populous479reinhold',
#  '49minicomputer337stahl',
#  '96scopic829grover',
#  '84hydrangea924perez',
#  '16psychotherapist336moloch',
#  '20tate510illinois',
#  '88compote637nw',
#  '98genuine163chaplin',
#  '73rose617nottingham',
#  '57chore947dee',
#  '81wipe139cantabrigian',
#  '75astrologer898tudor',
#  '50countervail100isaiah',
#  '22deerstalker386honshu',
#  '64faith694zimmerman',
#  '68limelight871hammond',
#  '26stationery480bailey',
#  '46rodent980percy',
#  '49sensual657ranier',
#  '52sidereal264netherlands',
#  '45rainfall193benton',
#  '64curlicue229dorset',
#  '68mutineer760tanaka',
#  '40skateboard784dorcas',
#  '76thereabouts202scandinavia',
#  '98roebuck361connors',
#  '38punctilious730tammany',
#  '34beaux414baffin',
#  '76manhole744yale',
#  '31theorist572passover',
#  '36accord845eagan',
#  '73erode252holyoke',
#  '33patchy173cheney',
#  '53droplet303marie',
#  '56florid857kashmir',
#  '46insatiable504wehr',
#  '97fullback815grossman',
#  '12she167matson',
#  '74whimsey461disney',
#  '68caret289archibald',
#  '21airway249juno',
#  '58exacerbate838lionel',
#  '98wrathful369belgium',
#  '51subvert752omaha',
#  '11hasty844ayers',
#  '89jockstrap396thule',
#  '26strict664thermofax',
#  '66exercise416achilles',
#  '18milch814garth',
#  '77phrasemake785uganda',
#  '79cell623marseilles',
#  '84honeymoon609vulcan',
#  '76jag462lourdes',
#  '79hummock588morley',
#  '34neuroanatomy792tudor',
#  '73temperance433wheller',
#  '46comprehensive181bema',
#  '95sear314yiddish',
#  '78pinochle437hurst',
#  '50hemp856etruscan',
#  '71subjunctive213lind',
#  '42goody270pauli',
#  '53collectible161stephen',
#  '50berne869muskegon',
#  '79dusky820harmon',
#  '81labial206garvey',
#  '31fence845jutish',
#  '72insignia176scotia',
#  '47woodhen628sabina',
#  '73conceptual161vega',
#  '93locus514mcdonnell',
#  '76par278hughes',
#  '42wasting738cortland',
#  '16biharmonic209vt',
#  '25coachmen269fiberglas',
#  '55knuckle812elgin',
#  '43macintosh202cretaceous',
#  '66birdie334monrovia',
#  '10whippet734sicilian',
#  '49deafen574osiris',
#  '97creed388u',
#  '14tangential825taurus',
#  '95fashion421millard',
#  '43ingather337lubbock',
#  '15flexible362wilkinson',
#  '86mung461laidlaw',
#  '32nearby835leighton',
#  '69legate829morrison',
#  '17aphasic746alex',
#  '76grandnephew213sanskrit',
#  '13shrub195earthman',
#  '70stationary514elkhart',
#  '42imbue469bergson',
#  '86transform596haines',
#  '10coupon732delphic',
#  '60perpetrate331dartmouth',
#  '46landscape535yugoslavia',
#  '51setback279hebraic',
#  '70stance262tunis',
#  '48urania846scylla',
#  '82habit200slovakia',
#  '99befallen887mcfarland',
#  '27aggregate580lottie',
#  '20soliloquy527pl',
#  '90guano743malthus',
#  '79coax749angie',
#  '83tarsier610ankara',
#  '25insult252araby',
#  '60rhesus688emery',
#  '89shoji358dorothea',
#  '65headwater749visigoth',
#  '16vitro730willard',
#  '37sack669analects',
#  '88cinematic418seminole',
#  '29crux617atropos',
#  '53tribute854bedford',
#  '55watchman979stephenson',
#  '37c858shockley',
#  '57octoroon299buchwald',
#  '54hornet241metzler',
#  '12coralberry661dis',
#  '77airy508monticello',
#  '71slab874pitt',
#  '72magnet277fm',
#  '99pyrotechnic789shreveport',
#  '87mastiff459tennyson',
#  '53trisyllable307bette',
#  '44intensive934newtonian',
#  '84stoneware128mcdaniel',
#  '44freight225jericho',
#  '86keep626jupiter',
#  '19sample499lyra',
#  '48prudential367tyrannosaurus',
#  '45andesine238cushman',
#  '94serendipity929linda',
#  '52columnar875pierson',
#  '35diety238ito',
#  '44buttercup724nina',
#  '74wont331gardner',
#  '46aurochs825dugan',
#  '28resistor371montclair',
#  '51mimic443pabst',
#  '18dungeon542diophantine',
#  '17sicken947circe',
#  '38stud548nazarene',
#  '17rage345hindi',
#  '27cardioid152pyrex',
#  '76zero787wappinger',
#  '35canoeist382hindi',
#  '61vulture974salvador',
#  '37thing877dostoevsky',
#  '77blandish670romanesque',
#  '20vortex925nimh',
#  '36deduct223cahill',
#  '35deoxyribose201hyman',
#  '39cutworm192rollins',
#  '93pediatrician939leeds',
#  '84octopus887marquette',
#  '56commensurable631templeton',
#  '68counterclockwise837clarendon',
#  '85venom534armata',
#  '64elsewhere801salerno',
#  '86kidney997blackburn',
#  '64append531antonio',
#  '96trunk633lindstrom',
#  '60persona848sheffield',
#  '94busy888waldron',
#  '47boycott113signor',
#  '98sashay548analects',
#  '54distribution135seidel',
#  '60introduce414lola',
#  '92trophy848blackfeet',
#  '54irredeemable966dutchmen',
#  '53cycle100indira',
#  '19thirtieth625mchugh',
#  '97exploitation922ursuline',
#  '96downstream726o',
#  '34administratrix626gallup',
#  '52coal944jorge',
#  '97upperclassman655hickey',
#  '10parapet756francisco',
#  '81jury444pickett',
#  '51ado941camembert',
#  '29raffia791roth',
#  '71ore156emmanuel',
#  '46soda550emory',
#  '66maharaja156ashley',
#  '30flood738neva',
#  '65botfly987chantilly',
#  '64grumble933hopkinsian',
#  '88capture213cambrian',
#  '61magnesium515schuylkill',
#  '84tapestry957biltmore',
#  '24toxin826tina',
#  '48loft215pease',
#  '85oak350arlington',
#  '28busload333bessemer',
#  '78scabrous456calumet',
#  '28touchdown762fda',
#  '75renaissance873reub',
#  '58rout360freetown',
#  '43manure779snider',
#  '34whomsoever475everhart',
#  '24thumbnail657nehru',
#  '49contest840mccracken',
#  '22cheer296antonio',
#  '96stiff633worthington',
#  '30grandnephew883gujarati',
#  '96brigadier484pergamon',
#  '32cadaverous539shiloh',
#  '21impeller785hetty',
#  '77serviceable443blanche',
#  '24expunge413wheller',
#  '94kelp912angela',
#  '21aristocracy365bernardino',
#  '18snail912kampuchea',
#  '57collet625medford',
#  '18sent646bayport',
#  '77schoolhouse866ama',
#  '26validate174loeb',
#  '45dockside139seymour',
#  '20traumatic555anastasia',
#  '39orthopedic519cohn',
#  '35rebel765cecil',
#  '56wayward514newark',
#  '58sandal537holmes',
#  '92suction684fresnel',
#  '41tantrum467atreus',
#  '14seater605tomlinson',
#  '61gangling387kenya',
#  '19zither103estes',
#  '77mare902stalin',
#  '73whom549corbett',
#  '96obstetric608midas',
#  '92hornmouth676galbreath',
#  '60cafeteria468lancaster',
#  '20awe820rudolf',
#  '11heartfelt122gwen',
#  '81chug596cyanamid',
#  '33icon391englewood',
#  '32histamine422carlton',
#  '98pushbutton258niobe',
#  '22turtleneck606jung',
#  '34trace454louis',
#  '88over564lester',
#  '31cohesion679cody',
#  '19diathesis718pbs',
#  '92durable535geminid',
#  '47sycamore367sorensen',
#  '96gallstone586herkimer',
#  '94grandson719newtonian',
#  '54standby675nato',
#  '24triangulate288dunlop',
#  '68paranoia243sacramento',
#  '83complimentary380swanson',
#  '18sallow419farmington',
#  '40shun709eunice',
#  '85honorary700i',
#  '13crypto636englander',
#  '51collect592scala',
#  '36hangover966watanabe',
#  '45hereto619margo',
#  '98lawgiver516hyades',
#  '86sprint156cambrian',
#  '76dose342nelsen',
#  '69medicate203hungary',
#  '19psychopomp126dunedin',
#  '92luge355wotan',
#  '18wallaby903theodore',
#  '56vertebrate552fuchsia',
#  '39talent469anaheim',
#  '15twentieth263texan',
#  '92breakfast393lundquist',
#  '69eel116capricorn',
#  '49fit302ms',
#  '46troff107tompkins',
#  '81inflammable297shelby',
#  '39boardinghouse750cinerama',
#  '39messieurs610briton',
#  '41phenyl835elsinore',
#  '59crocodilian290taylor',
#  '13taffeta623persephone',
#  '57solicitor279lange',
#  '15emittance945kamchatka',
#  '20shortcut362ave',
#  '57appetite243suffolk',
#  '92scavenge311paine',
#  '42throb911madison',
#  '97there',
#  '71conclusion532watson',
#  '59constituent526runnymede',
#  '45impiety272leopold',
#  '20vintage806hellenic',
#  '94regimentation971jeremy',
#  '26coin328goethe',
#  '30grateful670lucretia',
#  '57modesty655goode',
#  '38beet492icelandic',
#  '17perfumery618carboniferous',
#  '37boatyard797pleiades',
#  '72douse391ramsey',
#  '36gauche128sylvia',
#  '67bile728dailey',
#  '19postprocess335clark',
#  '93breech645kalamazoo',
#  '79coney688montgomery',
#  '75mycorrhiza332mario',
#  '87windsurf855marcy',
#  '19sixteenth933oneida',
#  '69burgeon786geigy',
#  '49tasteful433livermore',
#  '27spellbound468ted',
#  '42hellgrammite138kermit',
#  '49steadfast649schmitt',
#  '63filigree936gibbs',
#  '23oedipal217cantabrigian',
#  '35consular216mccoy',
#  '21exaggerate918veneto',
#  '87bah318damocles',
#  '18dry341maureen',
#  '32backside567bronx',
#  '65psychopathic172annie',
#  '14tong627mathieu',
#  '44registrant141sri',
#  '64bronchiole421marseilles',
#  '38denotative800freddie',
#  '10preparative726ritz',
#  '60rather722leslie',
#  '69victual311moliere',
#  '89gesticulate708harvard',
#  '90bowie946polyhymnia',
#  '51jalopy465ottawa',
#  '66algaecide210orkney',
#  '79semantic129ilona',
#  '34vinaigrette120senora',
#  '49percolate822wolfgang',
#  '25assignation533foote',
#  '67whither634actaeon',
#  '95quonset494belshazzar',
#  '87dachshund403eben',
#  '81kerosene706albania',
#  '17tau994baja',
#  '50machete712kessler',
#  '58psyche766kaufman',
#  '34spectrometer308platonist',
#  '19missionary764ernie',
#  '89verisimilitude779yaounde',
#  '93irrevocable631mcintyre',
#  '42boredom939wesley',
#  '35pattern149aitken',
#  '82convivial783hiawatha',
#  '96monkeyflower947palestine',
#  '42greenish292percival',
#  '32era608hiatt',
#  '97walnut686australis',
#  '34snippet700madras',
#  '82roadbed179motorola',
#  '11jaunty296gestapo',
#  '31insomniac247bahama',
#  '70expatriate182wesleyan',
#  '15slip884assam',
#  '20lodestone763willoughby',
#  '70flinty549scot',
#  '47mucosa157croatia',
#  '65oppose280bleeker',
#  '67marmoset319barrymore',
#  '21boon118wolfe',
#  '65backwood330marianne',
#  '38specious791mcconnell',
#  '20jimmy990riyadh',
#  '49formatted400douglass',
#  '97fuse306sheridan',
#  '93simper436davidson',
#  '44salvageable417lena',
#  '11couplet929orwellian',
#  '71gnostic936piscataway',
#  '83withdraw738salish',
#  '41now608sandusky',
#  '68arenaceous586lucia',
#  '76hellgrammite867isolde',
#  '74dimethyl449johannes',
#  '27tail503pamela',
#  '63chip583markovian']

# %% [markdown]
# ### Pull all the addresses from the data variable

# %%
re.findall('Address:\s([0-9]*\s+\w*\s+\w*,\s+\w*\s+\w*,\s+\w*)', data)
# Out:
# ['541 Manchester Court, Sylvester MN, 72955',
#  '385 Nikko Ave, Philippine VA, 57874',
#  '533 Cezanne Ave, Opel NE, 59538',
#  '731 Amazon Ave, Motorola VA, 16698',
#  '709 Lebesgue Blvd, Jamaica UT, 69359',
#  '978 Matthew Ave, McPherson MN, 42178',
#  '158 McDaniel Ave, Kerouac LA, 91732',
#  '931 Ft Blvd, Sean AZ, 82177',
#  '877 Gegenschein Ave, Medford UT, 60919',
#  '794 Raphael Ave, Hugh NJ, 57959',
#  '383 Brenda Blvd, Hewitt DC, 95928',
#  '318 Eccles Lane, Thalia MS, 11084',
#  '366 WA Court, Binghamton IN, 29890',
#  '784 Fitchburg Blvd, Thracian OR, 47747',
#  '450 Germantown Blvd, Debussy AR, 72634',
#  '107 Sandia Ave, Fiberglas NM, 40232',
#  '948 Laurent Lane, Earthman AZ, 48043',
#  '785 Fullerton Ave, Draco ME, 22252',
#  '565 USC Court, Josiah MA, 43476',
#  '669 Edna Blvd, Hawaii TX, 89207',
#  '392 Bernini Blvd, Eben IA, 82537',
#  '702 PBS Lane, Vance NH, 43908',
#  '489 Nov Blvd, McDermott ID, 75424',
#  '388 Flanagan Lane, Batavia NH, 40420',
#  '867 Middlesex Ave, Bayda SD, 95209',
#  '696 Frazier Blvd, Senegal NE, 22237',
#  '815 Dakar Blvd, Uganda MS, 49660',
#  '248 Zurich Lane, Frick MN, 31508',
#  '882 Amoco Court, Lucas SC, 79297',
#  '935 Brett Court, Wilma NM, 56267',
#  '509 Marin Ave, Norris CA, 41434',
#  '434 Spencerian Lane, Boyce SD, 70803',
#  '407 Baudelaire Ave, Delphinus KY, 18805',
#  '715 Lamar Lane, Carey MI, 46073',
#  '929 Andover Ave, Elmira NM, 69884',
#  '802 Mizar Court, Kaplan CO, 89459',
#  '828 Paraguay Lane, Mobil IN, 58158',
#  '976 Toni Court, Netherlands NM, 83810',
#  '224 Tristan Blvd, Garry SC, 95991',
#  '184 USGS Lane, Calais NM, 69219',
#  '615 Soc Lane, Andrew TN, 20040',
#  '325 Everhart Court, Clark OH, 27977',
#  '416 Brian Court, Stewart NJ, 23911',
#  '484 Anita Lane, Tyler MT, 14140',
#  '830 Fitchburg Lane, Jimenez NM, 82049',
#  '863 Fibonacci Blvd, Araby AR, 54913',
#  '188 Ann Court, Manfred NE, 74025',
#  '478 Bose Blvd, Artemis HI, 64811',
#  '878 Carla Blvd, Tektronix IN, 74347',
#  '754 Sheppard Court, LSI WA, 25634',
#  '120 Hines Lane, EPA FL, 96597',
#  '261 Athabascan Lane, Quito AZ, 77382',
#  '182 Lowry Lane, SST TN, 81730',
#  '543 Gerhardt Ave, Vaudois MA, 10726',
#  '387 Hummel Ave, Frazier IN, 51077',
#  '978 Britannica Ave, Rowley SC, 48387',
#  '428 Silverman Blvd, Tennyson WV, 64014',
#  '674 Arlington Court, Hebrew MS, 90259',
#  '449 Crispin Blvd, Pittsburgh IL, 46830',
#  '819 Daytona Blvd, Finn SD, 96241',
#  '816 Perth Blvd, Oakley DC, 44106',
#  '279 Goldberg Lane, Kiwanis NJ, 58730',
#  '715 Dietrich Blvd, Muenster MD, 89929',
#  '723 Caucasus Blvd, Bowen MA, 93025',
#  '790 Urbana Lane, Hollywood UT, 64711',
#  '121 Anton Ave, Ethiopia IA, 42783',
#  '795 Sorensen Lane, Bette WI, 68458',
#  '709 Clifton Blvd, Diebold NH, 41918',
#  '880 Byzantium Ave, Hagen IL, 63109',
#  '875 TRW Blvd, Yorkshire CO, 60126',
#  '970 Markovian Court, Casanova ID, 69311',
#  '737 Edison Lane, Iraqi MA, 24646',
#  '655 NY Court, Spaulding OK, 76458',
#  '546 Chicago Court, Thule MN, 36814',
#  '769 Sikkim Blvd, Dr PA, 90376',
#  '200 Bern Court, Howard ND, 64967',
#  '772 Annie Ave, Connally MD, 78098',
#  '461 Blanchard Ave, Marcel SD, 36472',
#  '991 Marcia Blvd, Boylston AZ, 39376',
#  '189 Kessler Court, Hausa HI, 48143',
#  '750 Smythe Blvd, Richfield MT, 17362',
#  '177 Chicano Court, Araby CO, 62961',
#  '182 Waldo Court, Renoir OR, 47899',
#  '745 Julie Court, Mach DE, 20882',
#  '257 Socrates Blvd, Mendelian NY, 48738',
#  '791 Greenwich Lane, Allegheny NV, 77629',
#  '357 Ferrer Lane, Ian GA, 46852',
#  '563 Ethel Blvd, Bambi FL, 52305',
#  '503 Crestview Court, Juanita NY, 17694',
#  '832 Liverpool Court, Aires TX, 30024',
#  '621 Jarvin Ave, Houdini RI, 60159',
#  '758 Eunice Ave, Greenbelt MA, 63659',
#  '877 Goodwin Blvd, Michelin OH, 33442',
#  '171 Stanley Court, Ramada IN, 55669',
#  '981 Salerno Blvd, Morgan OR, 98164',
#  '112 Madrid Lane, Bartlett WY, 25765',
#  '837 Bootes Blvd, Dickson MI, 60340',
#  '872 Nestor Court, Lahore NM, 45972',
#  '473 Crimea Blvd, CIA NC, 73671',
#  '884 Abelson Blvd, Abo IA, 40963',
#  '216 Tanaka Ave, Basque DE, 84639',
#  '233 Pompeii Ave, Kristin UT, 61227',
#  '830 Orestes Blvd, Lounsbury CT, 89415',
#  '954 Nelsen Court, Gabriel HI, 56103',
#  '639 Falstaff Ave, Allis VT, 28851',
#  '148 Doria Ave, Ostrander NH, 28933',
#  '265 Renault Blvd, Sault WV, 89209',
#  '255 Audubon Lane, Adolphus IL, 78918',
#  '285 Elinor Lane, Boyd NY, 71968',
#  '870 Cottrell Lane, Delano NJ, 30506',
#  '138 Tuscan Ave, Tyburn PA, 14534',
#  '692 Arlen Court, Newport ME, 27575',
#  '445 Gustav Court, Gemini AZ, 24286',
#  '418 Tioga Court, Antietam SD, 39126',
#  '701 Christie Court, Lippincott VA, 43016',
#  '450 Paul Ave, Eagan IN, 68728',
#  '317 Buxtehude Ave, Debbie MO, 59302',
#  '883 Qatar Blvd, Bernie SD, 21153',
#  '958 Hokan Lane, Madison NV, 12682',
#  '238 Irish Lane, Johannesburg KY, 91703',
#  '327 Fulton Lane, Dougherty TX, 92189',
#  '998 Meredith Ave, Patagonia KS, 44470',
#  '780 Portuguese Ave, Shattuck TN, 40380',
#  '633 Storey Ave, Dunedin MT, 65403',
#  '133 Tampa Blvd, Pawtucket CT, 84350',
#  '329 Helvetica Ave, Tallahassee SC, 12743',
#  '786 Studebaker Court, Onondaga AK, 24899',
#  '900 Sorenson Ave, Lipton TX, 50216',
#  '303 Genoa Blvd, Finley TX, 82345',
#  '144 Astor Lane, Jason WA, 80724',
#  '415 Tutankhamen Court, Buick ME, 86048',
#  '169 Monsanto Blvd, Schroeder CA, 41018',
#  '541 Rex Ave, Algeria AK, 71765',
#  '532 SCM Lane, Sisyphus NV, 77732',
#  '868 Churchill Court, Klein HI, 79398',
#  '830 Avogadro Ave, Laramie NV, 71168',
#  '857 NY Ave, Missouri DE, 94198',
#  '390 Gibbs Lane, Geminid ID, 40645',
#  '521 Tanzania Blvd, Borden TN, 11120',
#  '113 Gus Lane, Utrecht CO, 63047',
#  '297 Rutledge Lane, Leroy WI, 13284',
#  '602 Bertha Blvd, Protophyta PA, 53017',
#  '643 Nathan Blvd, Sheridan NH, 80658',
#  '441 Feeney Lane, Blvd CT, 38678',
#  '129 Sternberg Court, Swahili NH, 63144',
#  '336 Gouda Court, Canaan OH, 85689',
#  '164 Elsie Court, Jill TX, 98679',
#  '979 Davy Lane, Kochab MS, 27869',
#  '490 Lockwood Ave, Hausa OH, 36016',
#  '716 Firestone Lane, Cathy SD, 78565',
#  '317 Rotarian Court, Jove ND, 17506',
#  '923 Biltmore Blvd, Briton SD, 95142',
#  '806 Lucifer Court, Konrad WI, 64352',
#  '129 Nguyen Ave, Eastman KY, 16966',
#  '660 Anacreon Blvd, Howell NH, 50962',
#  '686 Poughkeepsie Court, Daugherty ND, 77711',
#  '274 Cushing Blvd, Rumford IN, 66579',
#  '520 ITT Blvd, Fontainebleau AK, 66443',
#  '628 Margo Ave, Wappinger RI, 44205',
#  '886 Sykes Lane, Tehran GA, 35841',
#  '908 Rica Ave, Europa AZ, 28236',
#  '308 Johnston Blvd, Sarasota IN, 55729',
#  '548 Pabst Blvd, Epiphany MD, 38851',
#  '452 Kumar Lane, Ogden GA, 18207',
#  '646 Cramer Court, Johannesburg MO, 97164',
#  '944 Luxembourg Lane, Galveston NY, 96445',
#  '433 NOAA Blvd, Gobi NJ, 62776',
#  '919 Muscat Lane, Amelia TX, 46440',
#  '949 Menlo Blvd, Castro MA, 43997',
#  '823 Odin Court, Kabul MS, 62035',
#  '226 Saud Blvd, AK NH, 38157',
#  '331 Cayuga Ave, Timon ME, 51033',
#  '332 Leone Court, Brendan IL, 38072',
#  '356 Calvary Ave, Ed MI, 89114',
#  '449 Protozoa Ave, Helena KY, 30482',
#  '139 Floyd Blvd, Hattie NM, 28935',
#  '380 Natalie Lane, Bentham NE, 87890',
#  '313 OPEC Ave, Moorish WY, 73764',
#  '847 Melpomene Lane, Marcello IN, 98927',
#  '409 Pentateuch Blvd, Moyer TN, 54720',
#  '412 Carbondale Ave, Orwell CT, 56503',
#  '938 November Ave, Alabama AR, 83009',
#  '801 Fairchild Court, Colorado CA, 32446',
#  '854 Diebold Lane, Mitchell MI, 73169',
#  '649 Venus Ave, Sadie VA, 99399',
#  '229 Hecuba Court, Copernicus NE, 92797',
#  '521 Arkansas Ave, Culver NM, 77411',
#  '607 Nancy Ave, Connally ME, 60819',
#  '896 Denebola Lane, Abbott NC, 11166',
#  '722 Lacerta Ave, Cepheus AZ, 45484',
#  '618 Gregg Blvd, Calumet MI, 24030',
#  '318 Polk Blvd, Aegean LA, 91738',
#  '559 Louisiana Blvd, Lockwood MI, 82922',
#  '419 AL Ave, Hopi LA, 35780',
#  '883 Dido Lane, Nadine DE, 69119',
#  '972 Calvary Lane, Gonzalez DC, 83596',
#  '417 Hopkins Blvd, Geiger MO, 56555',
#  '349 Christenson Court, Irene NY, 89337',
#  '230 Michaelangelo Lane, Hyde SD, 50948',
#  '479 Thursday Blvd, Rosenthal OH, 67282',
#  '546 Coddington Court, BTL MN, 85786',
#  '555 Pentecost Lane, Lydia NY, 37221',
#  '213 Borealis Ave, Loren MT, 42230',
#  '197 Valois Court, Manchester IL, 99117',
#  '989 Atropos Court, Dar WV, 96279',
#  '332 Klan Lane, Gouda CO, 79418',
#  '833 Schlesinger Court, Vella ND, 78839',
#  '865 Lemuel Ave, Strom IL, 42819',
#  '345 Scythia Court, Cheddar CT, 13133',
#  '140 Principia Court, Orin NY, 81166',
#  '577 Dacca Ave, Pollard IL, 71485',
#  '432 Jeremiah Ave, Formica AZ, 10719',
#  '382 Goldwater Court, Sistine MI, 69122',
#  '894 Farnsworth Lane, Brindisi LA, 66741',
#  '985 Athens Blvd, Siegmund FL, 13091',
#  '884 Schenectady Blvd, Hartford WI, 69313',
#  '813 Andover Blvd, Essex DE, 79092',
#  '291 Allah Court, Hungary AZ, 47954',
#  '845 Beaujolais Court, Yorkshire NM, 73765',
#  '661 Bleeker Blvd, Bedford NJ, 28111',
#  '673 Markovian Ave, Gould HI, 48545',
#  '721 Khartoum Ave, Philippine CT, 82318',
#  '896 Ganymede Lane, Hitachi TX, 59198',
#  '269 Argonaut Court, Olsen IL, 14887',
#  '483 Feldman Court, Singapore MT, 36199',
#  '247 Swaziland Lane, Lauderdale NH, 67331',
#  '376 Orr Lane, Agway VA, 59967',
#  '250 Corbett Ave, Abyssinia KY, 81200',
#  '463 Noll Ave, Callisto ND, 18331',
#  '179 Kiowa Ave, Barnabas OH, 57986',
#  '254 Socrates Court, Curtis WV, 36155',
#  '423 Abigail Blvd, Brittany CO, 16653',
#  '191 Preston Ave, Northrop HI, 28976',
#  '554 Confucian Blvd, Brest ND, 45949',
#  '190 Doyle Ave, Madeira MT, 95396',
#  '642 McGowan Lane, Cunningham SC, 74205',
#  '135 Haitian Blvd, Grecian PA, 38318',
#  '665 Amharic Ave, Yaqui FL, 28000',
#  '145 Coddington Court, Koch NJ, 77962',
#  '402 Gustavus Lane, Newsweek AZ, 98766',
#  '268 Wilkes Blvd, McElroy SC, 92130',
#  '222 McKenna Blvd, Chablis ID, 89298',
#  '339 Antoine Court, Iran TN, 84521',
#  '534 Meiji Ave, Keith KY, 25478',
#  '611 Bridgetown Lane, Europa IA, 42322',
#  '772 Cyprian Blvd, Algenib MA, 24361',
#  '424 Siegel Court, Pakistan VA, 75447',
#  '694 Klein Ave, Kurt OK, 38832',
#  '402 Calvary Ave, Indianapolis MA, 96230',
#  '583 Aruba Lane, Sturbridge NC, 58104',
#  '418 Yoder Blvd, Carlton DC, 87674',
#  '991 Chinook Blvd, Lakehurst CO, 78010',
#  '109 Fourier Blvd, Stanley WY, 22557',
#  '134 Hitler Lane, Kirby FL, 35908',
#  '873 Northrup Lane, Benedictine TX, 77413',
#  '875 Afghanistan Ave, Sharpe NH, 20860',
#  '574 Mont Lane, Mateo KS, 49274',
#  '926 Yosemite Lane, Bunsen IN, 29329',
#  '975 Jeff Ave, Rutledge FL, 20212',
#  '679 Jones Lane, Simonson NJ, 17906',
#  '147 Audubon Court, Sanskrit MS, 77194',
#  '344 Bennett Blvd, Aubrey MT, 99726',
#  '975 Camino Court, Vienna NM, 32363',
#  '820 Piraeus Blvd, Cameroun MI, 26459',
#  '530 Christie Lane, IQ VT, 64338',
#  '517 Kamchatka Court, Hanlon HI, 51704',
#  '395 Elmer Court, Clarendon CA, 43880',
#  '433 Sault Lane, Tel MN, 48898',
#  '238 Costello Lane, Fruehauf AK, 37265',
#  '442 Dawson Court, Berkshire AR, 80093',
#  '564 Adair Blvd, Japan CO, 55872',
#  '365 Chile Court, Belgium PA, 82738',
#  '597 Greensboro Lane, Ferrer WV, 19257',
#  '404 Engel Court, Tallahassee AK, 83273',
#  '575 Logan Court, Liggett TX, 32024',
#  '468 FM Ave, Fahey IL, 52142',
#  '892 Crusoe Court, Istvan TX, 85706',
#  '544 William Blvd, Emerson WI, 60053',
#  '940 USC Blvd, Epicurean IN, 13520',
#  '167 Kingsley Blvd, Jugoslavia VA, 28477',
#  '803 Knauer Lane, Nazi NE, 59971',
#  '650 Tarrytown Blvd, Liverpudlian CT, 73861',
#  '104 Chinaman Lane, Anita OH, 22560',
#  '564 Devonshire Blvd, Wadsworth VT, 21532',
#  '591 Morton Lane, Salina TN, 83130',
#  '228 Mississippian Lane, McLeod TX, 32759',
#  '497 Virgil Court, Electra AZ, 93681',
#  '794 McKee Ave, Shulman DC, 84679',
#  '398 Lundberg Blvd, Julia MN, 85527',
#  '387 Mansfield Lane, Leon MD, 77729',
#  '932 NCR Lane, Ursa IL, 99843',
#  '399 Haberman Blvd, Avery IN, 36413',
#  '249 Cartesian Lane, Perry RI, 87410',
#  '476 Argentinian Ave, DNA AR, 84178',
#  '124 Jurassic Ave, Seattle UT, 80277',
#  '532 Morrison Blvd, Arkansas WA, 57023',
#  '333 Magdalene Blvd, Adolphus AR, 35642',
#  '523 Geigy Blvd, Pulitzer SC, 58766',
#  '271 Philip Blvd, Bessemer CA, 48453',
#  '343 Mukden Blvd, Knightsbridge OR, 13320',
#  '219 Clyde Ave, Tuscany MA, 97860',
#  '552 Pittston Court, Cavendish FL, 64271',
#  '299 McLaughlin Blvd, Rio DE, 66299',
#  '983 Circe Court, Iran TX, 40132',
#  '317 Kernighan Lane, Horace KS, 38501',
#  '302 Lindstrom Lane, Englewood WI, 99628',
#  '546 Eugene Lane, Jed IA, 99606',
#  '747 Helmholtz Lane, Josef MS, 31908',
#  '391 Achaean Ave, Bert AK, 88392',
#  '279 WY Court, Selwyn DE, 23864',
#  '888 Cargill Ave, Holcomb AK, 78918',
#  '855 Iranian Lane, Eratosthenes ME, 37184',
#  '378 Euridyce Blvd, Boeing NY, 94764',
#  '450 Celia Court, Davies UT, 52579',
#  '799 Starr Blvd, Teresa MD, 34153',
#  '292 Wiley Blvd, Dutchmen ME, 83700',
#  '869 Thailand Blvd, Allyn ND, 35617',
#  '648 Kremlin Blvd, England MO, 89626',
#  '818 Einstein Court, Anabel NJ, 38769',
#  '425 Dunbar Lane, Nichols WV, 79643',
#  '401 Redstone Ave, Hugh AK, 45593',
#  '511 USPS Court, Seminole CO, 51670',
#  '783 Corcoran Court, Buttrick ND, 24612',
#  '698 Agee Blvd, Ramsey AR, 60791',
#  '659 Gustave Blvd, Burundi AR, 85893',
#  '795 Fujitsu Lane, Hitchcock OR, 15856',
#  '225 Coulter Ave, Zaire PA, 61173',
#  '116 Camille Lane, Laotian GA, 64970',
#  '508 Veneto Court, Craig DE, 27695',
#  '356 Englishmen Court, Michele FL, 98867',
#  '208 Marlborough Blvd, Notre NY, 26237',
#  '455 Borneo Ave, Cinderella KY, 54786',
#  '865 Baudelaire Court, Jurassic PA, 50155',
#  '111 Brownian Blvd, Uganda AK, 96471',
#  '957 Boris Court, Magdalene WI, 92227',
#  '672 Fayetteville Blvd, Castillo NY, 44156',
#  '983 Reginald Court, Seagram LA, 26810',
#  '146 Lagrange Blvd, Technion CT, 68944',
#  '196 Bessie Blvd, Bini DC, 13970',
#  '819 Auckland Ave, Bess PA, 31946',
#  '207 Appian Ave, Isfahan NM, 85537',
#  '284 Craig Lane, Eucharist NH, 63322',
#  '692 Blythe Lane, Paraguayan OH, 69422',
#  '355 USAF Blvd, Lieberman WV, 39677',
#  '585 Engle Ave, Korea NY, 45697',
#  '335 Pickering Court, Chinese TX, 98593',
#  '368 Harris Lane, Parthia WV, 24277',
#  '120 Shelton Lane, Enos UT, 24683',
#  '143 Sancho Ave, Eastman CA, 90261',
#  '804 Jesus Ave, Engle WV, 82643',
#  '113 Allentown Court, Schoenberg UT, 59839',
#  '870 Katmandu Court, Ulan NV, 72288',
#  '854 Missy Lane, Greenbriar IL, 13420',
#  '716 Minos Blvd, Istanbul DE, 60877',
#  '794 Mont Blvd, Sampson MI, 17631',
#  '305 Precambrian Blvd, Titan SD, 38329',
#  '677 Verona Lane, Vega VT, 67339',
#  '321 Switzer Ave, Italian NH, 63339',
#  '495 Francine Court, Whitehall CO, 14419',
#  '179 Benz Lane, Alicia TX, 74164',
#  '172 Thea Blvd, Sturm TX, 31095',
#  '925 Arcadia Ave, Melvin DE, 74321',
#  '207 Alfred Ave, Vaughan WY, 65843',
#  '880 Mouton Ave, Madonna IL, 10436',
#  '942 Calcutta Blvd, Germany MT, 83016',
#  '814 Oppenheimer Lane, Lowry VA, 89715',
#  '367 Antaeus Lane, Kankakee NE, 53287',
#  '619 SCM Blvd, Tel MS, 61754',
#  '233 York Court, Elijah SC, 45656',
#  '962 Cyanamid Lane, Miles NV, 42480',
#  '523 Durrell Court, Tuscarora VT, 48845',
#  '770 McKinney Court, Sussex VT, 51435',
#  '663 Houdini Blvd, Kowalewski CT, 32227',
#  '864 Dartmouth Lane, Cyclops OK, 53988',
#  '663 Klein Court, Eunice MA, 46136',
#  '948 Henderson Blvd, Faustus RI, 14876',
#  '165 Amelia Court, Cambrian NE, 78392',
#  '587 Norma Ave, Stirling AR, 77587',
#  '597 Elmer Blvd, EEOC MT, 64950',
#  '568 Opel Court, Huggins CO, 31037',
#  '583 Auckland Blvd, Vietnam TN, 51890',
#  '933 Vienna Ave, Hurst KS, 23133',
#  '748 Hereford Lane, Sagittarius OK, 42977',
#  '225 Cauchy Court, Sargent NY, 57608',
#  '220 Gurkha Lane, Rene NV, 74360',
#  '101 Amherst Ave, Segovia TX, 22606',
#  '204 Hyman Lane, Andover NV, 53101',
#  '473 Lloyd Court, Carlton IN, 70724',
#  '938 Valery Court, Thrace MA, 21756',
#  '663 Coates Lane, Loomis FL, 91398',
#  '560 Dolan Ave, Kovacs VA, 13940',
#  '136 Cassiopeia Lane, Anabel WV, 89381',
#  '307 Rushmore Blvd, Fredrickson MT, 58325',
#  '163 Tyrannosaurus Lane, Hammond RI, 31344',
#  '813 Poisson Blvd, Fullerton IL, 43693',
#  '635 Brie Lane, Plainfield NM, 95835',
#  '758 Kant Lane, Willard FL, 86566',
#  '939 Pergamon Blvd, Veneto NV, 80645',
#  '114 Manama Lane, Azores MA, 12907',
#  '238 Lucretia Blvd, Angeline PA, 57316',
#  '543 Chesapeake Court, Buttrick AK, 95720',
#  '160 Burnham Blvd, Layton DC, 66763',
#  '474 Mackey Ave, Edgerton GA, 41929',
#  '266 Saturday Blvd, Koch LA, 98487',
#  '450 FMC Ave, Volterra OK, 55930',
#  '682 Freudian Court, Pullman OH, 73045',
#  '225 Shepard Blvd, Vesuvius ND, 49618',
#  '482 Caribbean Blvd, Schenectady CT, 96487',
#  '381 Octavia Lane, Byron MO, 72226',
#  '133 Brie Lane, Muir OH, 56013',
#  '328 Sabina Court, Islam NJ, 57665',
#  '240 Brahmsian Blvd, Olivia NY, 15444',
#  '358 Cahill Blvd, Livermore LA, 43006',
#  '169 Mardi Court, Socratic NM, 36535',
#  '818 Canaveral Lane, Cretaceous VA, 29037',
#  '249 Alexandria Lane, Bose WA, 97148',
#  '383 Senegal Blvd, Haiti LA, 18922',
#  '539 Mynheer Ave, Peoria CT, 25716',
#  '425 Po Court, Parke MO, 87774',
#  '912 Kruse Court, Jackman OR, 61670',
#  '202 Adonis Blvd, Ullman NC, 79333',
#  '193 Youngstown Ave, IBM RI, 30532',
#  '823 Shattuck Lane, Dwyer RI, 99189',
#  '922 Sumatra Lane, Saracen NH, 29437',
#  '464 MacKenzie Court, Aurelius WI, 13026',
#  '716 Adrienne Blvd, Bonaparte KS, 78092',
#  '680 Foote Ave, Neapolitan WV, 27137',
#  '557 Siegmund Court, Yuki WI, 38481',
#  '984 Aeneid Court, Paulette NV, 81499',
#  '513 Thoreau Blvd, Micronesia HI, 17056',
#  '261 Niamey Lane, Iberia ID, 47371',
#  '509 Rodney Ave, Richmond ME, 58191',
#  '105 Shreveport Ave, Fuchsia AZ, 75286',
#  '898 Klaus Ave, Telex ME, 62916',
#  '456 Falkland Court, Merck NY, 38997',
#  '706 Dane Blvd, Ponce DE, 75530',
#  '639 Ephesian Lane, Larson MI, 18563',
#  '924 Isaacson Blvd, Moliere VA, 85287',
#  '779 Gunderson Lane, Ptolemy MN, 22344',
#  '100 Shirley Ave, Abe SC, 37988',
#  '609 Ariadne Ave, Tyrannosaurus KS, 30499',
#  '869 Zeiss Lane, Rigel UT, 85028',
#  '558 Corsica Blvd, Frigidaire KY, 65707',
#  '512 Beauregard Ave, Pittston RI, 94766',
#  '109 Hanna Court, Delmarva AK, 86775',
#  '213 Ann Ave, Oxonian NY, 98644',
#  '611 Muenster Ave, Americana ND, 20692',
#  '638 Socratic Lane, Helena NJ, 63182',
#  '539 USGS Ave, Wyoming PA, 83052',
#  '111 Palmyra Ave, Sabina SD, 94649',
#  '466 Kant Blvd, Fresno IL, 94392',
#  '622 Arthur Court, Rowley MN, 54319',
#  '123 Allegra Blvd, Hermes MO, 32309',
#  '899 Hines Court, Spokane IN, 78793',
#  '227 Clausius Ave, Doherty AZ, 47375',
#  '484 UN Lane, Moliere MN, 95541',
#  '521 Orwell Lane, Hyannis SD, 72387',
#  '600 Kensington Court, Vance PA, 59630',
#  '256 Blomberg Court, Yorkshire OK, 78072',
#  '329 Benjamin Court, Pomona ND, 80665',
#  '141 Wiley Blvd, Dwyer TX, 14337',
#  '986 Beltsville Court, Leopold MD, 77764',
#  '940 Dakota Ave, PBS SD, 19657',
#  '574 Lars Blvd, Stokes PA, 63489',
#  '276 Saxon Blvd, Truman IL, 15886',
#  '944 Patton Court, NC AR, 40507',
#  '599 Emanuel Court, Braun MN, 85271',
#  '283 TNT Blvd, Moroccan SC, 81346',
#  '462 Bette Ave, Tiber TN, 84895',
#  '580 Porto Ave, Shannon IA, 23885',
#  '551 Chablis Lane, Schmidt OR, 21945',
#  '156 Viet Ave, Linnaeus AR, 43272',
#  '582 Murphy Ave, Borg DE, 67710',
#  '263 Caesarian Blvd, Madagascar UT, 77438',
#  '135 Greensboro Court, Gujarati MI, 84996',
#  '848 Michaelangelo Ave, Baltimorean NY, 93547',
#  '770 Humphrey Blvd, Agway MS, 82605',
#  '316 Simmons Court, Ezekiel UT, 17920',
#  '641 Amoco Blvd, Galway ME, 66104',
#  '639 Kalmuk Court, Mobil DE, 49483',
#  '772 McDonnell Blvd, Louvre KY, 59076',
#  '877 Fredholm Lane, TRW NC, 69956',
#  '620 Muong Court, Sachs GA, 72060',
#  '446 Jaime Lane, Kalmuk MI, 78614',
#  '319 Pleiades Blvd, Persia DC, 84987',
#  '429 Toshiba Court, Negroid WI, 38430',
#  '792 Reynolds Lane, Fraser MA, 25658',
#  '501 Roberta Ave, Gemini NJ, 12586',
#  '209 Keaton Court, Swahili LA, 51385',
#  '138 Burlington Lane, Holm CO, 28717',
#  '103 Boyce Blvd, Exxon OH, 80369',
#  '648 Yonkers Lane, Michael NV, 92788',
#  '711 Cecilia Ave, McLean RI, 78020',
#  '865 Alvin Ave, Parsifal NY, 54598',
#  '490 Lockwood Court, Percival SC, 16873',
#  '155 Hoover Lane, Carla IL, 41107',
#  '989 Stafford Ave, Edwina MI, 58413',
#  '968 Cowan Court, Frigidaire VA, 97875',
#  '809 Everhart Court, Abelson KS, 62513',
#  '438 Wightman Court, Crawford TN, 36702',
#  '357 Candide Blvd, Marion TN, 89644',
#  '844 Bristol Ave, Stephanie RI, 67085',
#  '342 Fairfax Ave, Parke IL, 48979',
#  '366 Philistine Court, Proust UT, 90371',
#  '772 Zulu Court, Ramada OR, 34661',
#  '900 USPS Court, Jeres WA, 39702',
#  '578 Caputo Lane, Louvre RI, 84215',
#  '735 Gerard Lane, Floyd RI, 86058',
#  '975 Claire Ave, Mendel IL, 17991',
#  '560 Nazi Blvd, Mizar AZ, 83416',
#  '280 Lovelace Ave, Avery AK, 72814',
#  '755 PepsiCo Court, Theodore NM, 14438',
#  '818 Thetis Ave, Liverpool DE, 11687',
#  '979 Harrison Lane, Finnegan TN, 90119',
#  '152 Zoe Lane, Dusseldorf KS, 27275',
#  '446 Euterpe Ave, Gardner HI, 41194',
#  '638 Prof Ave, Charlotte NY, 53402',
#  '847 Bangladesh Ave, Yankee MD, 97708',
#  '839 GAO Blvd, Midwestern IA, 60289',
#  '192 Bartholomew Blvd, Texas NH, 44823',
#  '799 Stanhope Lane, French KS, 30932',
#  '119 Madame Ave, Shearer SD, 14207',
#  '615 Boyle Ave, Werther TN, 44543',
#  '279 Dairylea Court, Erik NY, 44431',
#  '726 Hickman Court, Igor UT, 51231',
#  '391 Rome Ave, Christ ME, 39923',
#  '102 Armenia Ave, Thursday WI, 87280',
#  '518 Odessa Lane, AK CO, 60938',
#  '237 FAA Blvd, Luis AZ, 60815',
#  '442 Palestine Court, Gino IL, 20364',
#  '539 Abernathy Lane, Waltham TX, 93077',
#  '268 Seneca Ave, Walcott TN, 26918',
#  '133 Charlemagne Court, Aphrodite TX, 73555',
#  '331 Aurelius Lane, Hummel TX, 43618',
#  '804 Sanskrit Court, Victoria MO, 42983',
#  '277 Charybdis Court, Augusta NH, 26730',
#  '897 Hornblower Lane, Volstead IL, 59574',
#  '512 Humboldt Court, Marino FL, 70455',
#  '795 Englishman Blvd, Dillon MD, 85114',
#  '776 Heckman Lane, Thorpe NV, 48040',
#  '879 Lotte Court, Mimi VA, 80067',
#  '412 Canaveral Court, Banbury MS, 97232',
#  '919 Virgil Lane, Quito DE, 26902',
#  '934 Breton Lane, Gerald NH, 96965',
#  '108 Suzanne Ave, Bellingham OK, 42963',
#  '831 Merle Ave, Carolingian SC, 20601',
#  '379 Angela Court, BSTJ AR, 23877',
#  '522 Armonk Blvd, Pakistani LA, 49295',
#  '783 Bryce Ave, Doreen AR, 32131',
#  '205 Stonehenge Ave, Slocum MN, 33574',
#  '824 Ferdinand Court, Kellogg ME, 55424',
#  '735 Galapagos Ave, Cervantes MT, 78248',
#  '353 Voss Court, Pasadena NV, 12191',
#  '898 Medusa Ave, Americana ND, 70264',
#  '257 Faustus Court, Ida CA, 33553',
#  '811 Czech Lane, Sheffield VA, 58492',
#  '538 Whitehall Court, Buxton CO, 64187',
#  '787 Allentown Blvd, Cruz MD, 49399',
#  '448 Minsky Lane, Leviticus MO, 41007',
#  '503 Curtis Lane, Lennox WV, 90483',
#  '699 Edwina Court, Cezanne NJ, 42553',
#  '301 Earthman Ave, Algeria WY, 97204',
#  '966 Gestapo Court, Munson AZ, 75296',
#  '407 Grumman Ave, Wallace ND, 20892',
#  '564 Alamo Blvd, Volterra FL, 75288',
#  '805 Wheller Ave, AC OK, 90462',
#  '324 Englishman Blvd, Derek AZ, 82311',
#  '118 Markovian Court, Vaughn KS, 61668',
#  '705 Spiegel Lane, Transvaal NY, 63696',
#  '550 Vida Court, Cobb NV, 67907',
#  '707 Asiatic Blvd, Almaden WI, 80656',
#  '572 Meiji Blvd, Murray DE, 63740',
#  '133 Ludwig Court, Sabina AZ, 91639',
#  '145 Jones Court, Danzig MS, 57734',
#  '744 IBM Ave, McDougall CT, 42633',
#  '383 Danish Ave, Damocles AR, 92258',
#  '195 Mathews Lane, Eire IL, 46756',
#  '974 Ridgway Court, Fairport TN, 45129',
#  '735 Timex Court, Nairobi MA, 46992',
#  '392 Bruckner Blvd, Constantinople OH, 37634',
#  '553 Hamlin Lane, Johann AK, 24990',
#  '966 Asilomar Ave, Waterhouse FL, 80509',
#  '601 Arequipa Court, Brookline AZ, 99829',
#  '751 Cooley Lane, Truk VA, 17214',
#  '952 Rembrandt Court, Jansenist CT, 63941',
#  '829 Paterson Lane, Protophyta CT, 21106',
#  '997 Piotr Blvd, Messiah NM, 60273',
#  '383 Billiken Court, Cal MO, 25986',
#  '773 Geigy Ave, Atkinson VT, 31708',
#  '135 Melanie Court, Lynchburg NY, 80160',
#  '698 DC Ave, Morrissey ID, 57232',
#  '285 Bennett Lane, Dyke DE, 42446',
#  '958 Lowell Court, Sunday OH, 26403',
#  '597 Higgins Lane, Giles CT, 78235',
#  '310 Calvin Lane, Mahayanist NV, 93961',
#  '556 Riyadh Ave, Leone FL, 13120',
#  '236 Billie Court, Ingersoll VT, 91445',
#  '931 Ervin Ave, Cantabrigian SC, 96382',
#  '869 Yorktown Blvd, Hess IN, 47634',
#  '736 TN Ave, McLeod AR, 46285',
#  '615 Hermes Lane, Yellowstone TN, 87657',
#  '616 Babcock Blvd, Chad IN, 72848',
#  '665 Baghdad Court, Burroughs NY, 87987',
#  '187 Pleistocene Blvd, Iraq IA, 27691',
#  '456 Feeney Ave, Medusa VA, 12769',
#  '199 Corbett Court, Hadamard HI, 91286',
#  '510 Rockford Lane, Honda TX, 78275',
#  '753 Bartlett Ave, Cruz NM, 21913',
#  '347 Nineveh Ave, Adolphus TN, 50922',
#  '541 Heidegger Blvd, Davidson CT, 23711',
#  '123 Norfolk Blvd, Rodriguez DE, 37616',
#  '922 Dartmouth Court, Jr MO, 50643',
#  '548 Dartmouth Lane, Coffey VA, 34683',
#  '163 Iranian Lane, Carmen OK, 55266',
#  '118 Sheraton Blvd, Oxford MA, 38664',
#  '137 Irene Court, Achaean MT, 63964',
#  '688 Athabascan Lane, Pabst NM, 92158',
#  '917 Tuscarora Court, Teresa OR, 96092',
#  '680 Eros Ave, Monterey PA, 64690',
#  '788 Roseland Lane, Mayo OK, 87162',
#  '408 Bertrand Ave, Barth KS, 35465',
#  '977 Angus Court, Mardi KS, 91785',
#  '626 Blackburn Court, Lise NC, 78680',
#  '881 Oakley Blvd, Allison DC, 59009',
#  '383 Townsend Court, Bini MO, 15838',
#  '414 Patton Blvd, Mabel WV, 54364',
#  '133 Zoe Court, Societe CO, 27853',
#  '518 Styx Blvd, Pete UT, 10596',
#  '671 Hottentot Ave, Bolshevist CO, 90992',
#  '359 Avernus Ave, Gatlinburg CO, 96975',
#  '852 Guenther Court, Cheney GA, 36115',
#  '897 Volta Blvd, Mauritania PA, 27077',
#  '615 Sam Lane, Crowley TX, 20039',
#  '104 Sheehan Court, Swaziland WA, 88208',
#  '448 Politburo Blvd, Theresa NY, 58000',
#  '538 Jericho Blvd, Buttrick SD, 76290',
#  '499 Dusenberg Court, Minoan NE, 33883',
#  '877 Deere Blvd, Ojibwa SC, 99411',
#  '295 Carl Lane, Whittaker CO, 79782',
#  '128 Rockies Court, Algeria NV, 16515',
#  '320 Gothic Lane, Cantonese UT, 72911',
#  '122 Clark Court, Muscovy OR, 22185',
#  '846 Mexican Lane, Monticello KS, 59562',
#  '881 Stockholm Lane, Friday MA, 51895',
#  '605 Jukes Lane, Jewett NH, 56553',
#  '200 Lehman Court, Hannah MN, 60542',
#  '222 Maharashtra Blvd, Casey TN, 63865',
#  '707 Mirfak Ave, Schoenberg MD, 71613',
#  '800 Kermit Court, Smucker CA, 11097',
#  '215 Gorham Ave, Salina NC, 86340',
#  '720 Edinburgh Court, Ross CT, 20672',
#  '356 Ruanda Ave, Aerobacter ME, 23597',
#  '208 Jason Blvd, Valhalla VA, 76792',
#  '483 Crockett Ave, Woolworth WI, 79341',
#  '537 Isolde Lane, SC MD, 15609',
#  '847 Runnymede Court, Yoder MT, 80003',
#  '994 Steiner Court, AK WA, 68875',
#  '357 Horus Lane, Matson NV, 66979',
#  '807 McKee Lane, Platonism NH, 73259',
#  '818 Gimbel Ave, Puccini TN, 88213',
#  '637 Vienna Ave, Wallis KY, 10868',
#  '408 Salk Ave, Patton NE, 78762',
#  '381 Nicodemus Court, Rockies WA, 49892',
#  '599 Eugenia Ave, Ukrainian WV, 83346',
#  '460 Rutherford Lane, Frye VA, 33603',
#  '667 Jose Lane, TX NJ, 30333',
#  '592 Hanover Ave, Stahl SC, 32974',
#  '542 Luther Lane, Bergstrom SD, 95827',
#  '904 Freddie Lane, Thracian ID, 74653',
#  '195 Walsh Court, Hodgkin NV, 98908',
#  '563 OPEC Court, Essen MN, 43823',
#  '893 Agatha Ave, Galileo KS, 53284',
#  '998 Volterra Court, Chad ID, 95950',
#  '121 Sunday Court, Delphinus AR, 67602',
#  '541 Pritchard Court, Trichinella NE, 99474',
#  '589 Creole Lane, Mohawk WA, 31945',
#  '460 Moll Court, Milton NE, 35589',
#  '927 Dis Court, Melanie MI, 12332',
#  '625 Harold Court, EST UT, 81543',
#  '838 Kafkaesque Lane, Cunningham NM, 31369',
#  '837 Judas Ave, Macedonia PA, 22240',
#  '730 Euridyce Court, Eloise SC, 99931',
#  '223 Swedish Ave, Custer AK, 71431',
#  '661 Hugo Ave, UT ID, 75223',
#  '255 Balinese Court, Bridget MO, 91312',
#  '607 Ababa Blvd, Dennis ID, 54529',
#  '250 Apocrypha Court, Dionysian OH, 25262',
#  '384 Wier Ave, Hanukkah FL, 11163',
#  '254 Keaton Court, Nathaniel LA, 87408',
#  '136 Ervin Lane, Leigh AZ, 94874',
#  '490 Berlin Court, Bert NY, 80195',
#  '108 Koch Court, EDT KY, 79786',
#  '184 Neal Lane, Helen OR, 19040',
#  '409 Calais Lane, Yorktown NC, 32665',
#  '900 Alfred Lane, CERN NV, 66669',
#  '393 Havilland Lane, Baffin WV, 44725',
#  '562 Nellie Blvd, Jakarta CT, 63968',
#  '373 Analects Blvd, Israelite DC, 13817',
#  '499 Gerber Court, Sextans ND, 22707',
#  '309 Moran Ave, Riga MN, 97650',
#  '598 Dairylea Court, WA NM, 29893',
#  '227 Schuylkill Lane, Lenten NC, 20374',
#  '846 Tarzan Court, Walcott OK, 65866',
#  '135 Irwin Blvd, Trojan WV, 53401',
#  '806 Fatima Blvd, Delaware OH, 76660',
#  '914 Bergstrom Blvd, Schweitzer IN, 42435',
#  '611 Marie Ave, Charybdis NC, 26313',
#  '555 Adelaide Ave, Honduras ME, 46746',
#  '260 Donaldson Court, Calhoun UT, 34541',
#  '155 Romeo Ave, Nicholson MO, 54950',
#  '900 Frey Court, Ammerman MI, 64178',
#  '454 Haney Ave, Annette NC, 48231',
#  '111 Klan Ave, Edgar NC, 22990',
#  '701 Dylan Lane, Arab NE, 83746',
#  '622 Garfield Court, Jewish NM, 63592',
#  '958 Borden Ave, Lucifer AZ, 70287',
#  '720 Dobbin Ave, Clayton NE, 59056',
#  '985 Dortmund Blvd, Wendy MA, 17333',
#  '389 Canfield Ave, Copenhagen KS, 52170',
#  '559 Millikan Court, Dinah NH, 59716',
#  '666 Teledyne Lane, Bolshoi KY, 35080',
#  '358 FL Blvd, Actaeon MA, 82791',
#  '502 Berkshire Blvd, Pelham MO, 99470',
#  '998 Rangoon Court, Gustave DC, 76458',
#  '225 Annette Blvd, Nero MT, 46529',
#  '653 Damascus Ave, Webb HI, 84543',
#  '422 AC Blvd, Amsterdam CO, 56399',
#  '208 Pavlovian Ave, Stockton CO, 80030',
#  '831 Karachi Ave, Hawaiian MS, 74868',
#  '681 Horatio Lane, Ashland KY, 12238',
#  '752 Indianapolis Ave, Elsevier NE, 75163',
#  '482 Mycenaean Lane, Ontario SC, 74786',
#  '538 Salvador Blvd, Gaspee TX, 14796',
#  '650 Abramson Lane, Virginia OR, 23828',
#  '200 Ian Ave, Dwyer OK, 80911',
#  '576 USDA Lane, Rosa WV, 54953',
#  '470 Herculean Ave, IRS IA, 20751',
#  '285 Ritchie Ave, Bayport NM, 72657',
#  '801 Abo Ave, Mont KS, 38746',
#  '921 Sadler Ave, Virgo IN, 61465',
#  '797 Huston Ave, Sikh NM, 93231',
#  '371 Franz Ave, Edwardian OH, 17209',
#  '334 Olson Lane, Eucharist WI, 19334',
#  '995 Avery Ave, Boris RI, 78933',
#  '767 Renoir Court, Isaiah AR, 84992',
#  '126 Augustus Ave, Britannica VA, 72298',
#  '405 Westfield Lane, Faust CT, 64894',
#  '863 Manila Blvd, Bowditch WV, 30961',
#  '201 Wallis Lane, Oneida NE, 52129',
#  '274 Vella Court, Juanita WV, 23103',
#  '984 Rhenish Blvd, Charlie OH, 21023',
#  '377 Fizeau Court, Shannon NC, 60847',
#  '418 Sylvania Court, Palmolive KY, 56444',
#  '594 Krakatoa Lane, Attica ME, 53907',
#  '419 Jules Blvd, Harcourt MO, 68672',
#  '925 Galbreath Ave, Papua NC, 47198',
#  '625 Wei Ave, Jennifer UT, 25226',
#  '625 Malton Court, Keats OH, 84651',
#  '487 Cranford Blvd, Alameda AR, 87801',
#  '501 Niagara Court, European TX, 55404',
#  '952 Suffolk Ave, Wilcox NE, 72547',
#  '593 Kruse Lane, Mafioso CA, 90552',
#  '233 Sunnyvale Court, Lykes OK, 85146',
#  '322 Cromwell Blvd, McConnel NH, 62880',
#  '397 Lou Lane, Watson IL, 28238',
#  '128 Thelma Court, Selena TN, 73690',
#  '904 Dow Blvd, Ukrainian KY, 26362',
#  '878 Zeiss Blvd, Ibn UT, 50918',
#  '248 Kennan Lane, Suez ID, 64984',
#  '206 Bellamy Court, Gorham NJ, 60652',
#  '664 Tuscarora Lane, Worcestershire TX, 36531',
#  '656 Avery Blvd, Aristotle MT, 48051',
#  '255 Mabel Lane, Canterbury TX, 52041',
#  '991 Ottoman Ave, Uranus NY, 23981',
#  '117 Alabamian Ave, Ephesus ND, 96127',
#  '831 Majorca Lane, Fontaine FL, 40001',
#  '734 Lucille Lane, Freddy NM, 89149',
#  '998 Bayonne Blvd, Karl MO, 21423',
#  '909 Riemann Court, Augusta WY, 24314',
#  '390 Tarbell Ave, Pocono OH, 94061',
#  '108 Nullstellensatz Court, Cyprus MD, 80565',
#  '998 NM Ave, Karp CT, 24933',
#  '777 Olduvai Lane, Crispin TX, 96004',
#  '769 Galois Ave, Norton WV, 57327',
#  '119 Matsumoto Lane, Monteverdi NV, 26584',
#  '875 Caroline Lane, Euripides WI, 63712',
#  '344 Salk Blvd, Leone SC, 25785',
#  '965 Josephine Blvd, Cossack KS, 41899',
#  '231 Cezanne Blvd, Larsen SD, 69690',
#  '689 NW Lane, Lyon VA, 83273',
#  '828 Mexico Court, Goa WV, 91758',
#  '931 Athabascan Court, Petersburg SD, 18640',
#  '502 Flagler Lane, Voss ID, 72312',
#  '206 Schuyler Ave, Ryder CT, 79026',
#  '721 Collins Lane, Indoeuropean PA, 96557']

# %% [markdown]
# ### Which state had the most addresses in your data?

# %%
import pandas as pd
states = pd.Series(re.findall('\s([A-Z]{2}),', data))
states.value_counts()[0]
print 'Texas'
# Out:
# Texas

# %% [markdown]
# ### Do we have any famous people in our data?
# #### Check to see if there are any user names that are also city/street names

# %%
names = re.findall('Name:\s(\w*\s+\w*)', data)
streets = re.findall('Address:\s[0-9]*\s+(\w*)\s', data)
fam = []
for i in names:
    for j in streets:
        if j in i:
            if i not in fam:
                fam.append(i)
fam
# Out:
# ['Wotan Mirfak',
#  'Lindstrom Anglophobia',
#  'Oedipus MacMillan',
#  'Stanhope Errol',
#  'Coffman Eagan',
#  'Josephson Lounsbury',
#  'Venusian Pearson',
#  'Marlboro Mississippian',
#  'Magdalene Peruvian',
#  'Augustus Gail',
#  'Holstein Freya',
#  'Levine Armageddon',
#  'Sistine Amarillo',
#  'Lindquist McKeon',
#  'Helena Werner',
#  'Stearns Urdu',
#  'Sanchez SIAM',
#  'Mohammedan Banach',
#  'Kaskaskia Bathurst',
#  'Cyclops Cornelius',
#  'Hieronymus NCR',
#  'Mateo Ptolemy',
#  'Peru Chauncey',
#  'York Melbourne',
#  'Hartford Goldstein',
#  'OPEC Laughlin',
#  'Mrs Hoyt',
#  'Coleman Machiavelli',
#  'Percival Carthage',
#  'Actaeon Kaplan',
#  'Hugh Alexandra',
#  'Shakespearian Cicero',
#  'Kilimanjaro Michelin',
#  'Lachesis Shari',
#  'Frederic Kidde',
#  'Barnard Otis',
#  'Formosa Sandusky',
#  'Darius Segundo',
#  'Britannica Heinrich',
#  'Thessaly Aylesbury',
#  'Keller Mullen',
#  'Mohammed Harriman',
#  'Damocles Icarus',
#  'Burroughs Rhine',
#  'America Stanton',
#  'Carib Buchwald',
#  'Jutland Sappho',
#  'Laotian Lucas',
#  'Alhambra Glasgow',
#  'Whalen Liberia',
#  'Albany Broadway',
#  'Jesuit Phillip',
#  'Midas Promethean',
#  'Indoeuropean Kigali',
#  'Copernican Edith',
#  'Carolyn Jan',
#  'Laramie Damascus',
#  'Maharashtra Irishman',
#  'Tipperary A',
#  'Peking Tuscan',
#  'Lang Conestoga',
#  'Kipling Hecate',
#  'Melbourne Alberto',
#  'SSE Sumatra',
#  'Telex Singapore',
#  'Charlotte Hoboken',
#  'Cluj Danzig',
#  'Bert Hollerith',
#  'Huntington Europa',
#  'Irrawaddy Stockholm',
#  'Cenozoic Halstead',
#  'Hurd Freudian',
#  'Sammy Alabamian',
#  'Joan Jacobean',
#  'Romanesque Alpert',
#  'Morrill Jutish',
#  'Mel Edmonds',
#  'Britannica Katharine',
#  'Betsy Orlando',
#  'Cromwell Senora',
#  'Monterey Bauhaus',
#  'Margery Lola',
#  'Penn Tomlinson',
#  'Lounsbury Shannon',
#  'NH Frau',
#  'Alberta Whitehorse',
#  'Datsun Politburo',
#  'Cassandra Butterfield',
#  'Honshu Alistair',
#  'Neanderthal Bimini',
#  'Marcy Garibaldi',
#  'Mayer Oberlin',
#  'USIA Washington',
#  'Isaacson Dairylea',
#  'Mavis Riggs',
#  'Lindsey Godfrey',
#  'Frick Paoli',
#  'Gemini Igor',
#  'Campbell Weinstein',
#  'Dhabi Hausa',
#  'CACM Sisyphus',
#  'UK Macbeth',
#  'NCAA CERN',
#  'Maureen Poynting',
#  'Domesday Jim',
#  'Durrell Plutarch',
#  'Glasgow ERDA',
#  'Garcia Clinton',
#  'Kirchoff Lagrange',
#  'Burt Frau',
#  'Maynard Shulman',
#  'Nate Perseus',
#  'Lauderdale NOAA',
#  'Singapore Schumann',
#  'Frye Indonesia',
#  'Paso Auberge',
#  'Xhosa Elmira',
#  'NIH Goodrich',
#  'Jericho Bauer',
#  'Provence Aylesbury',
#  'Delft Aegean',
#  'Jacqueline Libya',
#  'Paoli Rhode',
#  'Ritter Carleton',
#  'Chablis Gillespie',
#  'Schmidt Torrance',
#  'Costello Earthman',
#  'Knudsen Czerniak',
#  'Catherine Watson',
#  'Aden Gottfried',
#  'Meyer Ave',
#  'Schumacher Hathaway',
#  'September Almaden',
#  'Argus Horton',
#  'Olivier Hinman',
#  'Victoria Mavis',
#  'Ukraine Czech',
#  'Haifa Jarvin',
#  'Lyon Whitaker',
#  'Bremen Yale',
#  'Jacob Debby',
#  'Alexandre Blackwell',
#  'Caucasus Madonna',
#  'Nibelung Dante',
#  'TOEFL Deimos',
#  'Delft McNally',
#  'Sophie Granville',
#  'Cheney Baird',
#  'Judy Cassandra',
#  'Winnipeg Hayes',
#  'Hurd Kidde',
#  'Webb Saunders',
#  'Elisabeth Sancho',
#  'Actaeon Po',
#  'Stockholm Fullerton',
#  'Roland AC',
#  'Hawaii Raphael',
#  'Vicky Carla',
#  'Ponce Hoboken',
#  'Pittsfield Buddhism',
#  'Marcia Shoshone',
#  'Kingsbury Naomi',
#  'Freeport Krakatoa',
#  'Loren Lansing',
#  'Sperry Burnside',
#  'Antony Seville',
#  'Orinoco Carlisle',
#  'Pearce Sardinia',
#  'Rowena Cassius',
#  'Leibniz Amharic',
#  'Indonesia Carib',
#  'Grady Budweiser',
#  'Ovid Blackwell',
#  'Baltimorean Oldsmobile',
#  'Ashland Croix',
#  'Coriolanus Worcester',
#  'Amharic Welles',
#  'Swedish Mayer',
#  'Iranian Romulus',
#  'Heinz Casanova',
#  'Cesare Castillo',
#  'Carey Kitakyushu',
#  'Neanderthal Patrice',
#  'Teflon Maxwellian',
#  'Brandon Magruder',
#  'Kowalski Mohammedan',
#  'Busch Wang',
#  'Reynolds Larsen',
#  'Holmes Britannic',
#  'Piraeus Platonist',
#  'Schmidt Baird',
#  'Heidegger Yugoslavia',
#  'NCAA Ku',
#  'Iran Haddad',
#  'Driscoll Elmira',
#  'Moen Runnymede',
#  'Mafioso Middlesex',
#  'Ephesus Crestview',
#  'Della Olson',
#  'Bernet Ingersoll',
#  'Meyer Cornelius',
#  'Pancho Benz',
#  'Knutson Baffin',
#  'Samuel Garry',
#  'Ann Bismarck',
#  'Nate Kyle',
#  'Octavia Harbin',
#  'Michelin Indiana',
#  'Wyeth Monaco',
#  'Cinerama Icarus',
#  'Stanley Kyoto',
#  'CIA Kikuyu',
#  'Greenberg Bertha',
#  'Compton Coddington',
#  'Merritt Aristotelean',
#  'Konrad Triassic',
#  'Negro Holstein',
#  'Moses Neumann',
#  'Thayer Lachesis',
#  'Huber Rafael',
#  'Otto Kirchoff',
#  'Frye Celanese',
#  'Atkinson Peale',
#  'Coventry Jewell',
#  'Rhodesia Cunard',
#  'Molly Barrington',
#  'Giacomo Ektachrome',
#  'Weller Koenig',
#  'Katherine Hepburn',
#  'Dryden Mellon',
#  'PepsiCo Gettysburg',
#  'Damocles Canaveral',
#  'Pergamon Rodriguez',
#  'Mooney Monterey',
#  'Capistrano NASA',
#  'Eagan Ziegler',
#  'Kenney Moscow',
#  'Corvus Mozart',
#  'Elysee Tulane',
#  'Bloomington Glaswegian',
#  'Wyoming Halley',
#  'Mississippi Coolidge',
#  'Schmidt Mysore',
#  'Addison Monsanto',
#  'Gerald MacGregor',
#  'Ivanhoe Sian',
#  'Paula Judas',
#  'Leviticus McIntosh',
#  'Arkansan Seville',
#  'Biggs Melanesia',
#  'Talmudic Grosset',
#  'Schumann Barton',
#  'Michelin Vientiane',
#  'Seville Volvo',
#  'Riemannian Tampa',
#  'Ito Jacobsen',
#  'Montevideo Kidde',
#  'Platonism Kitakyushu',
#  'Mary RCA',
#  'Ku Lear',
#  'Knightsbridge Fleming',
#  'Monash Kigali',
#  'Caldwell Dairylea',
#  'Nassau Atkins',
#  'Carla Sibley',
#  'Buddhist Henri',
#  'Charlie Runnymede']

# %% [markdown]
# ### What is the value count of the zipcodes in your addresses?

# %%
zips = pd.Series(re.findall('[0-9]{5}', data))
len(zips.value_counts())
# Out:
# 790
